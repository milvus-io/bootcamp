# %% [markdown]
# # Movie Recommender System
#
# In this example you will create a movie recommender system.
#
# The system will extract feature vectors from metadata about films using SentenceTransformers, import those vectors into Milvus, and import the metadata into Redis.When a user submits information about movies they're interested in, you'll search Milvus for similar films and provide searchers movie info from Redis using the results.
#
# ## Requirements
# - Python 3.x.
# - Docker
# - A system with at least 32GB of RAM, or a Zilliz cloud account

# %% [markdown]
# ## Data
#
# In this project, you'll use [The Movies Dataset from Kaggle](https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset/data). This dataset contains metadata on more than 45k movies.
#
# The dataset has several files, but you'll only need **movies_metadata.csv,** the main Movies Metadata file. You can use this notebook as a starting point and modify it to take advantage of the rest of this dataset.

# %% [markdown]
# # Requirements
#
# First, install the Python packages needed for this project.

# %%
! python -m pip install pymilvus redis pandas sentence_transformers kaggle

# %% [markdown]
# ## Download dataset
#
# Now you'll download the dataset. You'll use the [Kaggle API](https://github.com/Kaggle/kaggle-api) to retrieve the data.
#
# Set your login information below, or download **kaggle.json** to a location where the API will find it.

# %%
# %env KAGGLE_USERNAME=username
# %env KAGGLE_KEY=XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %env TOKENIZERS_PARALLELISM=true

# %% [markdown]
# Download the data and unzip it to the **dataset** directory.

# %%
import kaggle

kaggle.api.authenticate()
kaggle.api.dataset_download_files('rounakbanik/the-movies-dataset', path='dataset', unzip=True)

# %% [markdown]
# ## Milvus Server
#
# You're going to create vector embeddings from the movie's descriptions. So, you need a way to store, index, and search on those embeddngs. That's where Milvus comes in.
#
# This is a relatively large dataset, at least for a server running on a personal computer. So, you may want to use a Zilliz Cloud instance to store these vectors.
#
# But, if you want to stay with a local instance, you can download a docker compose configuration and run that.
#
# Here's how to get the compose file, and start the server.

# %%
! wget https://github.com/milvus-io/milvus/releases/download/v2.3.0/milvus-standalone-docker-compose.yml -O docker-compose.yml
! docker-compose up -d

# %% [markdown]
# But, if you want to use cloud, sign up for an account [here](https://cloud.zilliz.com).

# %% [markdown]
# ## Redis Server
#
# You're using Redis as a metadata storage service. Start it with docker.

# %%
! docker run --name redis -d -p 6379:6379 redis

# %% [markdown]
# Read in the movie metadata and see what it has to offer.

# %%
import pandas as pd

movies=pd.read_csv('dataset/movies_metadata.csv',low_memory=False)
movies.shape
# Out:
# (45466, 24)

# %% [markdown]
# Youhave more than 45k movies, with 24 columns of metadata.
#
# List the columns.

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# There's no need to store all these columns in Redis. Trim them down to the essentials.

# %%
trimmed_movies = movies[["id", "title", "overview", "release_date", "genres"]]
trimmed_movies.head(5)
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                             overview release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...   1995-12-15
# 2  A family wedding reignites the ancient feud be...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...   1995-12-22
# 4  Just when George Banks has recovered from his ...   1995-02-10
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]

# %% [markdown]
# Now, it's time to connect to Milvus and Redis so you can start uploading data.
#
# Start with Redis:

# %%
import redis                    
redis_server = redis.StrictRedis(host="localhost", port=6379)
redis_server.flushall()
# Out:
# True

# %% [markdown]
# Next, connect to Milvus.
#
# Here's the code for connecting to a cloud instance. Replace the URI and TOKEN with the correct values for your instance.
#
# You can find them in your Zilliz dashboard:
#
#
# ![image.png](cluster_info.png)

# %%
from pymilvus import *
import redis

milvus_uri="https://in03-75204f04fc4368d.api.gcp-us-west1.zillizcloud.com"
token="12ac8d384a8bae99c7fe00e34c112aa4095034cf45c7db6e5d8be9f974dbb737b116e983fbd350f6cf2e75406a74b7d030fc814e"
connections.connect("default",
                        uri=milvus_uri,
                        token=token)
print("Connected!")
# Out:
# Connected!

# %% [markdown]
# Start by importing the movie metadata into Redis. While you're doing this, clean up the data by verifying that all the fields are present before inserting the entry into Redis. Many of the movies are missing fields, especailly the critical **overview**.
#
# By removing the bad entries from the list, you'll leave yourself with a dataset that matches Redis and is save to transform into embeddings.

# %%
import json
from pprint import pprint

movies_dict = trimmed_movies.to_dict('records')

for movie in movies_dict:
    if not movie["id"] or movie["overview"] != movie["overview"] or movie["release_date"] != movie["release_date"] or movie["genres"] != movie["genres"]:
        print("Dropping:")
        pprint(movie)
        movies_dict.remove(movie)

    redis_server.set(str(movie['id']), json.dumps(movie))

print("Done importing movies into redis.")
# Out:
# Dropping:
# {'genres': "[{'id': 10749, 'name': 'Romance'}, {'id': 12, 'name': "
#            "'Adventure'}]",
#  'id': '78802',
#  'overview': nan,
#  'release_date': '1996-09-18',
#  'title': 'Wings of Courage'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]",
#  'id': '161495',
#  'overview': nan,
#  'release_date': '1995-03-01',
#  'title': 'Roommates'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '287305',
#  'overview': nan,
#  'release_date': '1996-03-21',
#  'title': 'Peanuts – Die Bank zahlt alles'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '10801',
#  'overview': nan,
#  'release_date': '1996-03-06',
#  'title': 'The Superwife'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '278978',
#  'overview': nan,
#  'release_date': '1996-02-29',
#  'title': 'Und keiner weint mir nach'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10769, 'name': 'Foreign'}]",
#  'id': '117730',
#  'overview': nan,
#  'release_date': '1994-01-01',
#  'title': 'Under The Domim Tree'}
# Dropping:
# {'genres': '[]',
#  'id': '365371',
#  'overview': 'Seven New Zealand women speak about their lives during World War '
#              'II: some lost husbands, some got married, some went into service '
#              'themselves. The director lets the women tell their stories '
#              'simply, alternating between them talking and archival footage of '
#              'the war years.',
#  'release_date': nan,
#  'title': 'War Stories Our Mother Never Told Us'}
# Dropping:
# {'genres': '[]',
#  'id': '215107',
#  'overview': 'Vermont is for Lovers is an independently produced docudrama '
#              'released in 1992, starring George Thrush and Marya Cohn and shot '
#              'on location Tunbridge, Vermont. The film concerns a couple '
#              'visiting Vermont in order to be married, and interviewing local '
#              'residents on the subject of marriage.[Largely improvised and '
#              'using non-professional actors, the film was shown at various '
#              'film festivals including the Melbourne International Film '
#              'Festival and the Hawaii International Film Festival. The movie '
#              'was not terribly well received by the national press, with the '
#              'New York Times calling it, "vaguely amiable". While the '
#              'Washington Post review commented that the film was an '
#              '"all-too-easy target for ridicule", it also mentioned one of the '
#              'film\'s high points: "In one scene, a typically droll Vermont '
#              "resident (playing himself) sums up his state's fabled coolness "
#              'to strangers by suggesting that a sign be placed at the state '
#              'line, reading "Welcome to Vermont. Now Leave.""',
#  'release_date': nan,
#  'title': 'Vermont Is for Lovers'}
# Dropping:
# {'genres': '[]',
#  'id': '281085',
#  'overview': nan,
#  'release_date': '1996-05-22',
#  'title': 'A Boy Called Hate'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '282919',
#  'overview': nan,
#  'release_date': '1996-06-20',
#  'title': 'Diebinnen'}
# Dropping:
# {'genres': '[]',
#  'id': '48144',
#  'overview': nan,
#  'release_date': '1994-01-01',
#  'title': 'The Day the Sun Turned Cold'}
# Dropping:
# {'genres': '[]',
#  'id': '145925',
#  'overview': nan,
#  'release_date': '1993-01-01',
#  'title': 'Mille bolle blu'}
# Dropping:
# {'genres': "[{'id': 53, 'name': 'Thriller'}]",
#  'id': '253632',
#  'overview': nan,
#  'release_date': '1988-10-08',
#  'title': 'Baton Rouge'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '108365',
#  'overview': nan,
#  'release_date': '1996-09-09',
#  'title': 'The Proprietor'}
# Dropping:
# {'genres': "[{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '146341',
#  'overview': nan,
#  'release_date': '1995-09-12',
#  'title': 'Bird of Prey'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}, {'id': "
#            "10749, 'name': 'Romance'}, {'id': 10769, 'name': 'Foreign'}]",
#  'id': '43775',
#  'overview': nan,
#  'release_date': '1995-01-01',
#  'title': 'Guantanamera'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '60083',
#  'overview': nan,
#  'release_date': '1996-11-20',
#  'title': 'Salut cousin !'}
# Dropping:
# {'genres': '[]',
#  'id': '77314',
#  'overview': nan,
#  'release_date': '1991-12-04',
#  'title': 'The Cabinet of Dr. Ramirez'}
# Dropping:
# {'genres': '[]',
#  'id': '134368',
#  'overview': nan,
#  'release_date': '1998-10-09',
#  'title': 'One Tough Cop'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '94214',
#  'overview': 'Jails, Hospitals &amp; Hip-Hop is a cinematic tour de force that '
#              'is unprecedented in film or hip-hop history. From the mind of '
#              'Brooklyn actor, performance artist and hip-hop activist Danny '
#              'Hoch, this film spins out the stories of ten lives shocked by '
#              'global hip-hop, the prison system and life in general. Moving '
#              'masterfully in and out of the characters while the camera cuts '
#              'from film narrative to live performances, Danny blows your mind '
#              'and makes you look at cultural power in a new way that is '
#              'hysterically funny, tragically sad and uplifting all at once.',
#  'release_date': nan,
#  'title': 'Jails, Hospitals & Hip-Hop'}
# Dropping:
# {'genres': '[]',
#  'id': '207731',
#  'overview': 'Tommy, a talented Puerto Rican painter living in the South '
#              "Bronx, befriends Allen, a white kid who's faced constant "
#              'harassment since moving to the neighborhood with his single '
#              'mother, Susan.',
#  'release_date': nan,
#  'title': "Boricua's Bond"}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}, "
#            "{'id': 10749, 'name': 'Romance'}]",
#  'id': '109472',
#  'overview': nan,
#  'release_date': '2001-06-06',
#  'title': 'The Girl'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '78657',
#  'overview': nan,
#  'release_date': '2000-09-06',
#  'title': 'Ouch'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 10769, 'name': 'Foreign'}]",
#  'id': '58886',
#  'overview': nan,
#  'release_date': '2000-04-12',
#  'title': "Everybody's Famous!"}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, "
#            "{'id': 10769, 'name': 'Foreign'}]",
#  'id': '99885',
#  'overview': "Four friends fight an insane man's crusade to eliminate sinners "
#              'from a small Western town.',
#  'release_date': nan,
#  'title': 'Divine Intervention'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '29224',
#  'overview': nan,
#  'release_date': '1982-09-17',
#  'title': 'Jönssonligan & DynamitHarry'}
# Dropping:
# {'genres': '[]',
#  'id': '81346',
#  'overview': nan,
#  'release_date': '1982-03-01',
#  'title': 'To Begin Again'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10769, 'name': 'Foreign'}]",
#  'id': '61939',
#  'overview': nan,
#  'release_date': '2002-01-01',
#  'title': 'The Three Marias'}
# Dropping:
# {'genres': '[]',
#  'id': '65048',
#  'overview': nan,
#  'release_date': '1962-01-01',
#  'title': 'The Four Days of Naples'}
# Dropping:
# {'genres': '[]',
#  'id': '53688',
#  'overview': nan,
#  'release_date': '1991-03-03',
#  'title': 'Stinsen brinner... filmen alltså'}
# Dropping:
# {'genres': '[]',
#  'id': '175739',
#  'overview': nan,
#  'release_date': '2002-01-18',
#  'title': 'The Life of Aleksis Kivi'}
# Dropping:
# {'genres': "[{'id': 28, 'name': 'Action'}, {'id': 27, 'name': 'Horror'}, "
#            "{'id': 878, 'name': 'Science Fiction'}]",
#  'id': '100594',
#  'overview': nan,
#  'release_date': '2003-03-06',
#  'title': 'The Book of Fate'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '32546',
#  'overview': nan,
#  'release_date': '2002-10-04',
#  'title': 'Lugares comunes'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]",
#  'id': '113178',
#  'overview': nan,
#  'release_date': '1999-01-01',
#  'title': 'A Wake in Providence'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '55396',
#  'overview': nan,
#  'release_date': '2004-02-12',
#  'title': 'Koirankynnen leikkaaja'}
# Dropping:
# {'genres': '[]',
#  'id': '68646',
#  'overview': nan,
#  'release_date': '2002-02-28',
#  'title': 'Superprodukcja'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 10769, 'name': 'Foreign'}]",
#  'id': '52920',
#  'overview': nan,
#  'release_date': '1978-12-08',
#  'title': 'What Will You Do When You Catch Me?'}
# Dropping:
# {'genres': '[]',
#  'id': '155386',
#  'overview': nan,
#  'release_date': '2005-01-01',
#  'title': 'La Sierra'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '22554',
#  'overview': nan,
#  'release_date': '2008-09-12',
#  'title': 'The Subtenant'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '47499',
#  'overview': nan,
#  'release_date': '2003-02-12',
#  'title': 'Small Cuts'}
# Dropping:
# {'genres': '[]',
#  'id': '55748',
#  'overview': nan,
#  'release_date': '2004-08-20',
#  'title': 'Ystäväni Henry'}
# Dropping:
# {'genres': '[]',
#  'id': '55500',
#  'overview': nan,
#  'release_date': '1993-04-30',
#  'title': 'The Land of Happiness'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '61070',
#  'overview': nan,
#  'release_date': '1954-07-30',
#  'title': 'Pekka ja Pätkä lumimiehen jäljillä'}
# Dropping:
# {'genres': '[]',
#  'id': '156908',
#  'overview': nan,
#  'release_date': '2009-03-01',
#  'title': 'Täynnä tarmoa'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '210487',
#  'overview': nan,
#  'release_date': '1969-02-20',
#  'title': 'Człowiek z M-3'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '38869',
#  'overview': nan,
#  'release_date': '1982-12-25',
#  'title': 'Wyjście awaryjne'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '155426',
#  'overview': nan,
#  'release_date': '2002-09-20',
#  'title': 'Anioł w Krakowie'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 53, 'name': 'Thriller'}]",
#  'id': '200796',
#  'overview': nan,
#  'release_date': '2003-03-19',
#  'title': 'Show'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, "
#            "{'id': 10769, 'name': 'Foreign'}]",
#  'id': '64968',
#  'overview': nan,
#  'release_date': '1997-01-01',
#  'title': 'Marius and Jeannette'}
# Dropping:
# {'genres': '[]',
#  'id': '156917',
#  'overview': nan,
#  'release_date': '1960-03-11',
#  'title': 'Pekka ja Pätkä neekereinä'}
# Dropping:
# {'genres': '[]',
#  'id': '91205',
#  'overview': 'Bling is a documentary film which focuses on the complex '
#              'relationship between “blood” diamonds, conflict, the influence '
#              'of Hip-Hop music and culture, and community development. '
#              'Produced by VH1 Rock Docs, Article 19 Films, and UNDP, the film '
#              'features the participation of Hip-Hop artists from the US and '
#              'Sierra Leone.  The objective of the film is not to shame people '
#              'into boycotting diamonds. Instead, it is to raise a voice on '
#              'behalf of the millions of diamond diggers and to help '
#              'disadvantaged communities and entrepreneurs reach their full '
#              'economic potential. Promoting conscious consumerism and using '
#              'the power and influence of the hip-hop music, Bling tries to '
#              'encourage buying "clean" diamonds.',
#  'release_date': nan,
#  'title': 'Bling: A Planet Rock'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}]",
#  'id': '66949',
#  'overview': nan,
#  'release_date': '1978-08-30',
#  'title': 'Molière'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': "
#            "53, 'name': 'Thriller'}, {'id': 10769, 'name': 'Foreign'}]",
#  'id': '128856',
#  'overview': nan,
#  'release_date': '2004-02-06',
#  'title': 'Traffic Affairs'}
# Dropping:
# {'genres': '[]',
#  'id': '154430',
#  'overview': nan,
#  'release_date': '2005-09-08',
#  'title': 'Shadow of the Eagle'}
# Dropping:
# {'genres': '[]',
#  'id': '41427',
#  'overview': nan,
#  'release_date': '2009-02-11',
#  'title': 'Questo piccolo grande amore'}
# Dropping:
# {'genres': "[{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}]",
#  'id': '140887',
#  'overview': nan,
#  'release_date': '1933-04-07',
#  'title': 'The Three Musketeers'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '18120',
#  'overview': nan,
#  'release_date': '2009-01-01',
#  'title': 'Brain Drain'}
# Dropping:
# {'genres': '[]',
#  'id': '63615',
#  'overview': nan,
#  'release_date': '2009-04-30',
#  'title': 'Un buen hombre'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]",
#  'id': '63764',
#  'overview': nan,
#  'release_date': '1947-09-22',
#  'title': 'Devil in the Flesh'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 37, 'name': 'Western'}]",
#  'id': '147683',
#  'overview': nan,
#  'release_date': '1978-02-12',
#  'title': 'The Prophet, the Gold, and the Transylvanians'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '148435',
#  'overview': nan,
#  'release_date': '1958-12-08',
#  'title': 'Pekka ja Pätkä Suezilla'}
# Dropping:
# {'genres': "[{'id': 28, 'name': 'Action'}, {'id': 37, 'name': 'Western'}]",
#  'id': '144089',
#  'overview': nan,
#  'release_date': '1978-12-22',
#  'title': 'The Actress, the Dollars and the Transylvanians'}
# Dropping:
# {'genres': "[{'id': 80, 'name': 'Crime'}, {'id': 37, 'name': 'Western'}]",
#  'id': '147692',
#  'overview': nan,
#  'release_date': '1981-01-12',
#  'title': 'The Oil, the Baby and the Transylvanians'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '62775',
#  'overview': nan,
#  'release_date': '2010-01-15',
#  'title': 'Havukka-Ahon Ajattelija'}
# Dropping:
# {'genres': '[]',
#  'id': '281287',
#  'overview': 'The real-life struggle to contain the environmental and '
#              'financial damage caused to Alaska by the oil spill from the '
#              'Exxon Valdez is dramatized.',
#  'release_date': nan,
#  'title': 'Dead Ahead: The Exxon Valdez Disaster'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '120280',
#  'overview': nan,
#  'release_date': '1955-03-04',
#  'title': 'Pekka ja Pätkä puistotäteinä'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '117499',
#  'overview': nan,
#  'release_date': '1968-12-20',
#  'title': 'Asphalt Lambs'}
# Dropping:
# {'genres': '[]',
#  'id': '21245',
#  'overview': nan,
#  'release_date': '2002-02-01',
#  'title': 'Lovers & Leavers'}
# Dropping:
# {'genres': '[]',
#  'id': '173865',
#  'overview': nan,
#  'release_date': '1994-11-10',
#  'title': 'Esa ja Vesa – auringonlaskun ratsastajat'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, "
#            "{'id': 10769, 'name': 'Foreign'}]",
#  'id': '30695',
#  'overview': nan,
#  'release_date': '2010-01-15',
#  'title': 'Chance Pe Dance'}
# Dropping:
# {'genres': '[]',
#  'id': '46341',
#  'overview': nan,
#  'release_date': '2006-08-14',
#  'title': 'El próximo Oriente'}
# Dropping:
# {'genres': '[]',
#  'id': '55403',
#  'overview': nan,
#  'release_date': '1999-02-19',
#  'title': 'Kulkuri ja joutsen'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10752, 'name': 'War'}]",
#  'id': '74714',
#  'overview': nan,
#  'release_date': '1992-03-04',
#  'title': 'Diên Biên Phu'}
# Dropping:
# {'genres': '[]',
#  'id': '90930',
#  'overview': nan,
#  'release_date': '1963-05-29',
#  'title': 'Strip-Tease'}
# Dropping:
# {'genres': "[{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '370264',
#  'overview': nan,
#  'release_date': '1995-05-31',
#  'title': 'Provocateur'}
# Dropping:
# {'genres': '[]',
#  'id': '157178',
#  'overview': nan,
#  'release_date': '1995-11-07',
#  'title': 'Grający z talerza'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '72421',
#  'overview': nan,
#  'release_date': '2009-04-10',
#  'title': 'Marcel Reich-Ranicki - Mein Leben'}
# Dropping:
# {'genres': '[]',
#  'id': '71732',
#  'overview': nan,
#  'release_date': '2006-07-19',
#  'title': 'The Right of the Weakest'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '116751',
#  'overview': nan,
#  'release_date': '1999-09-12',
#  'title': 'The Little Thief'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '65898',
#  'overview': nan,
#  'release_date': '1978-07-27',
#  'title': 'The Suspended Vocation'}
# Dropping:
# {'genres': '[]',
#  'id': '102527',
#  'overview': nan,
#  'release_date': '2009-09-01',
#  'title': '44500 Max'}
# Dropping:
# {'genres': '[]',
#  'id': '442417',
#  'overview': '52min | Documentary | TV Movie 12 January 2005',
#  'release_date': nan,
#  'title': 'Das Experiment 770 - Gebären auf Befehl'}
# Dropping:
# {'genres': '[]',
#  'id': '53364',
#  'overview': nan,
#  'release_date': '2010-11-11',
#  'title': 'Der letzte schöne Herbsttag'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '81414',
#  'overview': nan,
#  'release_date': '2010-04-30',
#  'title': 'Ingrid'}
# Dropping:
# {'genres': '[]',
#  'id': '54354',
#  'overview': nan,
#  'release_date': '2003-03-14',
#  'title': 'Eila'}
# Dropping:
# {'genres': '[]',
#  'id': '367647',
#  'overview': 'Documentary  Follow James Burke through the history of science '
#              'and technology. In this collection of 10 1-hour episodes, '
#              'starting with "The Trigger Effect".',
#  'release_date': nan,
#  'title': 'Connections'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '72375',
#  'overview': nan,
#  'release_date': '1999-02-24',
#  'title': 'Rien sur Robert'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '4880',
#  'overview': nan,
#  'release_date': '2006-11-29',
#  'title': 'Nichts als Gespenster'}
# Dropping:
# {'genres': '[]',
#  'id': '55408',
#  'overview': nan,
#  'release_date': '2002-08-30',
#  'title': 'Kymmenen riivinrautaa'}
# Dropping:
# {'genres': '[]',
#  'id': '145154',
#  'overview': nan,
#  'release_date': '2008-09-11',
#  'title': 'Ballou'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '3962',
#  'overview': nan,
#  'release_date': '2007-11-01',
#  'title': 'Bis zum Ellenbogen'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]",
#  'id': '74183',
#  'overview': nan,
#  'release_date': '2003-12-19',
#  'title': 'Vieraalla Maalla'}
# Dropping:
# {'genres': '[]',
#  'id': '55763',
#  'overview': nan,
#  'release_date': '1994-09-16',
#  'title': 'Vääpeli Körmy - Taisteluni'}
# Dropping:
# {'genres': '[]',
#  'id': '55761',
#  'overview': nan,
#  'release_date': '1992-10-09',
#  'title': 'Vääpeli Körmy ja etelän hetelmät'}
# Dropping:
# {'genres': '[]',
#  'id': '55754',
#  'overview': nan,
#  'release_date': '1991-10-18',
#  'title': 'Vääpeli Körmy ja vetenalaiset vehkeet'}
# Dropping:
# {'genres': '[]',
#  'id': '148314',
#  'overview': nan,
#  'release_date': '1997-09-26',
#  'title': 'Pekko ja Unissakävelijä'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '289010',
#  'overview': nan,
#  'release_date': '2008-10-27',
#  'title': 'Die Frau des Frisörs'}
# Dropping:
# {'genres': '[]',
#  'id': '55756',
#  'overview': nan,
#  'release_date': '1990-11-02',
#  'title': "Sergeant Körmy and the Marshall's Stick"}
# Dropping:
# {'genres': "[{'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}]",
#  'id': '36663',
#  'overview': 'A team of doctors experiment with a new, highly controversial '
#              'form of psycho therapy (named F.R.I.T.) designed to cure chronic '
#              'FEAR and PHOBIA patients. Soon someone begins to kill the '
#              'patients one by one and investigation uncovers that the patients '
#              'died in the exact way that they feared they would. Who or what '
#              'brought their fears to life?',
#  'release_date': nan,
#  'title': 'Dreamkiller'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '177697',
#  'overview': nan,
#  'release_date': '2009-10-14',
#  'title': 'Hangtime'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '404479',
#  'overview': nan,
#  'release_date': '2001-01-01',
#  'title': 'Car Bpnus'}
# Dropping:
# {'genres': '[]',
#  'id': '55166',
#  'overview': nan,
#  'release_date': '2000-03-03',
#  'title': 'Hurmaava joukkoitsemurha'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '230680',
#  'overview': nan,
#  'release_date': '2004-11-10',
#  'title': 'Nachbarinnen'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '92465',
#  'overview': nan,
#  'release_date': '2001-03-30',
#  'title': 'Ponterosa'}
# Dropping:
# {'genres': "[{'id': 10402, 'name': 'Music'}, {'id': 99, 'name': "
#            "'Documentary'}]",
#  'id': '105287',
#  'overview': nan,
#  'release_date': '2001-10-10',
#  'title': 'Super 8 Stories'}
# Dropping:
# {'genres': '[]',
#  'id': '132227',
#  'overview': nan,
#  'release_date': '2008-09-08',
#  'title': 'La próxima estación'}
# Dropping:
# {'genres': '[]',
#  'id': '72419',
#  'overview': nan,
#  'release_date': '2008-12-11',
#  'title': 'In jeder Sekunde'}
# Dropping:
# {'genres': '[]',
#  'id': '434973',
#  'overview': nan,
#  'release_date': '1999-03-12',
#  'title': 'Sokkotanssi'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}]",
#  'id': '86126',
#  'overview': nan,
#  'release_date': '2001-08-02',
#  'title': 'A Cab for Three'}
# Dropping:
# {'genres': '[]',
#  'id': '344741',
#  'overview': nan,
#  'release_date': nan,
#  'title': 'Pajęczarki'}
# Dropping:
# {'genres': '[]',
#  'id': '62614',
#  'overview': nan,
#  'release_date': '2011-01-01',
#  'title': 'Hella W'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '61121',
#  'overview': nan,
#  'release_date': '2007-09-07',
#  'title': 'Colorado Avenue'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}]",
#  'id': '74878',
#  'overview': nan,
#  'release_date': '1965-10-01',
#  'title': 'Cloportes'}
# Dropping:
# {'genres': '[]',
#  'id': '257608',
#  'overview': "Director Bahman Farmanara's second film following a 20-year "
#              'exile from his native Iran depicts the spiritual crisis of a '
#              "middle-aged man. In the film's dreamlike opening scene, Dr. Reza "
#              'Sepidbakht (Reza Kianian), a well-off Tehran gynecologist, '
#              'thinks he runs over an angel while driving home at night with a '
#              'call girl. The next morning at the hospital where he works, he '
#              'is shown a comatose boy who is famous for having memorized the '
#              'entire Koran. These two events cause him to rethink his cynical '
#              'outlook on life and his relationships with his elderly father, '
#              'wayward son, and the women he has mistreated since becoming '
#              'estranged from his wife. When the boy awakens from his coma, Dr. '
#              'Sepidbakht begins to look to him for answers.',
#  'release_date': nan,
#  'title': 'Khanei ruye ab'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]",
#  'id': '162374',
#  'overview': nan,
#  'release_date': '2010-11-15',
#  'title': 'Top Floor Left Wing'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]",
#  'id': '145594',
#  'overview': nan,
#  'release_date': '2003-09-12',
#  'title': 'Descongelate!'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '31337',
#  'overview': nan,
#  'release_date': '2009-03-19',
#  'title': 'Contact High'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '404471',
#  'overview': nan,
#  'release_date': nan,
#  'title': 'Pölynimurikauppiaat'}
# Dropping:
# {'genres': "[{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '247500',
#  'overview': nan,
#  'release_date': '2008-05-16',
#  'title': 'Le 7ème juré'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]",
#  'id': '85883',
#  'overview': nan,
#  'release_date': '2001-03-09',
#  'title': 'The Woman Who Drinks'}
# Dropping:
# {'genres': '[]',
#  'id': '399229',
#  'overview': nan,
#  'release_date': '1999-01-01',
#  'title': 'Kovat Miehet'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10752, 'name': 'War'}]",
#  'id': '86727',
#  'overview': nan,
#  'release_date': '1977-11-09',
#  'title': 'Le Crabe-Tambour'}
# Dropping:
# {'genres': "[{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '61361',
#  'overview': nan,
#  'release_date': '2002-09-10',
#  'title': "L'outremangeur"}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '362151',
#  'overview': nan,
#  'release_date': '1988-11-18',
#  'title': 'Nuoruuteni savotat'}
# Dropping:
# {'genres': '[]',
#  'id': '78999',
#  'overview': nan,
#  'release_date': '2008-09-17',
#  'title': 'Virtual JFK: Vietnam If Kennedy Had Lived'}
# Dropping:
# {'genres': "[{'id': 10752, 'name': 'War'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '116019',
#  'overview': nan,
#  'release_date': '2012-03-23',
#  'title': 'Taistelu Näsilinnasta 1918'}
# Dropping:
# {'genres': "[{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, "
#            "{'id': 35, 'name': 'Comedy'}]",
#  'id': '458428',
#  'overview': nan,
#  'release_date': '2009-11-01',
#  'title': 'Operación Cannabis'}
# Dropping:
# {'genres': '[]',
#  'id': '118013',
#  'overview': "Shaun Evans (The Take) steps into John Thaw's shoes as the "
#              "younger version of Colin Dexter's iconic creation, Inspector "
#              'Morse, shedding new light on the origins of the detective famed '
#              'for his love of crosswords, classical music, real ale, and '
#              'classic cars.',
#  'release_date': nan,
#  'title': 'Endeavour'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}, {'id': 12, 'name': "
#            "'Adventure'}, {'id': 36, 'name': 'History'}]",
#  'id': '110491',
#  'overview': nan,
#  'release_date': '2012-03-30',
#  'title': 'The Manzanar Fishing Club'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '79034',
#  'overview': nan,
#  'release_date': '2006-10-26',
#  'title': 'La Californie'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, "
#            "{'id': 10769, 'name': 'Foreign'}]",
#  'id': '35623',
#  'overview': nan,
#  'release_date': '2008-06-13',
#  'title': 'For My Father'}
# Dropping:
# {'genres': "[{'id': 12, 'name': 'Adventure'}, {'id': 35, 'name': 'Comedy'}, "
#            "{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]",
#  'id': '112973',
#  'overview': nan,
#  'release_date': '1996-06-07',
#  'title': "A Pig's Tale"}
# Dropping:
# {'genres': "[{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}, "
#            "{'id': 35, 'name': 'Comedy'}]",
#  'id': '76703',
#  'overview': nan,
#  'release_date': '1938-01-29',
#  'title': 'Quadrille'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '262988',
#  'overview': nan,
#  'release_date': '2002-07-02',
#  'title': 'The Men Who Made the Movies: Samuel Fuller'}
# Dropping:
# {'genres': "[{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, "
#            "{'id': 18, 'name': 'Drama'}]",
#  'id': '82663',
#  'overview': 'British soldiers force a recently captured IRA terrorist to '
#              'cooperate with them and then assign him to go undercover with a '
#              'gang of terrorists and prevent them from killing the U.S. '
#              "President. But the spy isn't in long before he realizes that the "
#              'first plot is but a ruse for a more sinister scheme that could '
#              'result in trouble between China and Great Britain.',
#  'release_date': nan,
#  'title': nan}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '156180',
#  'overview': nan,
#  'release_date': '2011-06-07',
#  'title': 'Amor?'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '62012',
#  'overview': nan,
#  'release_date': '1998-10-07',
#  'title': 'Le Poulpe'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '328712',
#  'overview': nan,
#  'release_date': '2010-09-04',
#  'title': 'Tarda estate'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '26152',
#  'overview': nan,
#  'release_date': '2009-04-08',
#  'title': 'Erreur de la banque en votre faveur'}
# Dropping:
# {'genres': "[{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, "
#            "{'id': 10769, 'name': 'Foreign'}]",
#  'id': '128637',
#  'overview': nan,
#  'release_date': '1988-01-01',
#  'title': 'American Roulette'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '64362',
#  'overview': nan,
#  'release_date': '2001-04-18',
#  'title': 'Oui, mais...'}
# Dropping:
# {'genres': '[]',
#  'id': '397339',
#  'overview': 'Black and White',
#  'release_date': nan,
#  'title': 'The Awful Truth'}
# Dropping:
# {'genres': '[]',
#  'id': '154792',
#  'overview': 'Filmmakers Joe Barber and Mary Patel examine the dysfunctional '
#              'world of American politics through the prism of the 2006 United '
#              'States Senate race between Democrat Bob Casey Jr. and Republican '
#              'Rick Santorum. Gullible media, corporate influence and '
#              'hyper-managed candidate personas are among the myriad subjects '
#              'covered in this incisive documentary, which includes interviews '
#              'with Barack Obama, Al Gore, Ed Rendell and many others.',
#  'release_date': nan,
#  'title': 'Electile Dysfunction: Inside the Business of American Campaigns'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 9648, 'name': 'Mystery'}, "
#            "{'id': 878, 'name': 'Science Fiction'}]",
#  'id': '177522',
#  'overview': nan,
#  'release_date': '1995-04-21',
#  'title': 'Lipton Cockton in the Shadows of Sodoma'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '72678',
#  'overview': nan,
#  'release_date': '2010-03-31',
#  'title': 'Henry'}
# Dropping:
# {'genres': '[]',
#  'id': '139909',
#  'overview': nan,
#  'release_date': nan,
#  'title': 'Aurinkotuuli'}
# Dropping:
# {'genres': '[]',
#  'id': '128644',
#  'overview': nan,
#  'release_date': '1993-01-17',
#  'title': 'Marked for Murder'}
# Dropping:
# {'genres': '[]',
#  'id': '367678',
#  'overview': 'American Documentary',
#  'release_date': nan,
#  'title': 'Enola Gay and the Atomic Bombing of Japan'}
# Dropping:
# {'genres': '[]',
#  'id': '76686',
#  'overview': nan,
#  'release_date': '2012-08-10',
#  'title': 'The Green Wave'}
# Dropping:
# {'genres': "[{'id': 878, 'name': 'Science Fiction'}]",
#  'id': '334317',
#  'overview': nan,
#  'release_date': '1993-04-05',
#  'title': 'Désiré'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '81225',
#  'overview': nan,
#  'release_date': '2011-03-31',
#  'title': 'Abendland'}
# Dropping:
# {'genres': "[{'id': 10770, 'name': 'TV Movie'}, {'id': 18, 'name': 'Drama'}, "
#            "{'id': 37, 'name': 'Western'}, {'id': 10749, 'name': 'Romance'}]",
#  'id': '134806',
#  'overview': nan,
#  'release_date': '1996-01-21',
#  'title': 'Riders of the Purple Sage'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '116059',
#  'overview': "Stand up comedian Graham Elwood's journey physically, and "
#              "emotionally, as he travels through Afghanistan's war zones to "
#              'entertain the embattled U.S. troops.',
#  'release_date': nan,
#  'title': 'Laffghanistan: Comedy Down Range'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '62130',
#  'overview': nan,
#  'release_date': '2008-06-01',
#  'title': 'El Big Bang de Tunguska'}
# Dropping:
# {'genres': '[]',
#  'id': '131822',
#  'overview': nan,
#  'release_date': '2012-09-28',
#  'title': 'Kuningas Litmanen'}
# Dropping:
# {'genres': '[]',
#  'id': '142989',
#  'overview': nan,
#  'release_date': '2005-09-28',
#  'title': 'A Get2Gether'}
# Dropping:
# {'genres': '[]',
#  'id': '54356',
#  'overview': nan,
#  'release_date': '2001-09-26',
#  'title': 'Emmauksen tiellä'}
# Dropping:
# {'genres': '[]',
#  'id': '149469',
#  'overview': nan,
#  'release_date': '2001-10-26',
#  'title': 'Carne de gallina'}
# Dropping:
# {'genres': "[{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '65646',
#  'overview': nan,
#  'release_date': '1943-12-13',
#  'title': 'The Eternal Return'}
# Dropping:
# {'genres': '[]',
#  'id': '55524',
#  'overview': nan,
#  'release_date': '1949-04-08',
#  'title': 'Prinsessa Ruusunen'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '82662',
#  'overview': nan,
#  'release_date': '2011-01-13',
#  'title': "L'industriale"}
# Dropping:
# {'genres': "[{'id': 53, 'name': 'Thriller'}]",
#  'id': '38875',
#  'overview': nan,
#  'release_date': '2008-10-17',
#  'title': 'Senność'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '388046',
#  'overview': nan,
#  'release_date': '2012-04-25',
#  'title': 'Donos de Portugal'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '67272',
#  'overview': nan,
#  'release_date': '2001-09-21',
#  'title': 'Känd från TV'}
# Dropping:
# {'genres': "[{'id': 10402, 'name': 'Music'}, {'id': 18, 'name': 'Drama'}, "
#            "{'id': 10769, 'name': 'Foreign'}]",
#  'id': '83342',
#  'overview': nan,
#  'release_date': '2011-12-28',
#  'title': 'Blutzbrüdaz'}
# Dropping:
# {'genres': "[{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, "
#            "{'id': 878, 'name': 'Science Fiction'}]",
#  'id': '93649',
#  'overview': 'Nadine (Lisa Sookhiram) is sucked into an otherworld through the '
#              "mirror -- but nobody knows it; they still see her, but it's her "
#              "reflection. Yet everyone's puzzled by the new Nadine's "
#              'aggressively sexual and dangerous behavior. Can her boyfriend, '
#              'Eric (James Kautz, former World Kickboxing Champion), stop her '
#              'from going down this path of destruction? Will the real Nadine '
#              'ever come back?',
#  'release_date': nan,
#  'title': 'Reflection'}
# Dropping:
# {'genres': '[]',
#  'id': '60824',
#  'overview': nan,
#  'release_date': '1991-05-22',
#  'title': 'Lune Froide'}
# Dropping:
# {'genres': '[]',
#  'id': '173914',
#  'overview': nan,
#  'release_date': '2013-03-07',
#  'title': 'Sēņotāji'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}]",
#  'id': '65958',
#  'overview': nan,
#  'release_date': '1992-12-23',
#  'title': 'The Supper'}
# Dropping:
# {'genres': "[{'id': 80, 'name': 'Crime'}, {'id': 35, 'name': 'Comedy'}, {'id': "
#            "10749, 'name': 'Romance'}]",
#  'id': '217038',
#  'overview': nan,
#  'release_date': '1990-02-01',
#  'title': 'Dolly and Her Lover'}
# Dropping:
# {'genres': '[]',
#  'id': '455027',
#  'overview': 'A film about a woman who doesn’t exist. Moroccan Hind was raped '
#              'and consequently denied an official identity – she has no other '
#              'choice but to work as a prostitute and traditional wedding '
#              'dancer, but despite the odds of her situation, refuses to give '
#              'up her dream of dignity, motherhood and love.  This is a story '
#              'of modern day outlaws, children of prostitutes, abandoned child '
#              'brides and those who have had to escape to the fringes of '
#              'patriarchal Moroccan society. Through the eyes of one young '
#              'woman we see a life of constant struggle, but also a life free '
#              'of the society’s norms and boundaries. The woman in the centre '
#              'of the film, Hind, is both vulnerable and courageous as she '
#              'tries to regain her life, her children and her mere right to '
#              'live as an equal human being in the 21st century.',
#  'release_date': nan,
#  'title': 'Dance of Outlaws'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '77776',
#  'overview': nan,
#  'release_date': '1999-07-07',
#  'title': 'La Dilettante'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '161073',
#  'overview': nan,
#  'release_date': '2013-01-23',
#  'title': 'Mariage à Mendoza'}
# Dropping:
# {'genres': "[{'id': 28, 'name': 'Action'}, {'id': 10769, 'name': 'Foreign'}, "
#            "{'id': 53, 'name': 'Thriller'}]",
#  'id': '19623',
#  'overview': nan,
#  'release_date': '2008-10-02',
#  'title': 'Drona'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '153196',
#  'overview': nan,
#  'release_date': '2009-10-31',
#  'title': 'Rosas Höllenfahrt'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '82627',
#  'overview': nan,
#  'release_date': '2010-03-14',
#  'title': "Man On a Mission: Richard Garriott's Road to the Stars"}
# Dropping:
# {'genres': '[]',
#  'id': '250503',
#  'overview': 'All Norah ever wanted to be was a reality TV star. But her '
#              'dream-come-true quickly turns into a nightmare when she allows a '
#              "motley television crew of chickens, led by a sociopath, 'Charlie "
#              "Chicken', to invade her home, manipulate her emotions, and drag "
#              'her and her soon-to-be-ex-boyfriend into the desert on what is '
#              'supposed to be a glamorous reality TV shoot. Deep in the surreal '
#              'landscapes of the Joshua Tree desert, it becomes a battle of '
#              'species. The hilarious antics of the oddball chicken crew, the '
#              'blind faith of a reality TV star wannabe, and the cruel '
#              "perversions of one really 'bad chicken', all spiral downward "
#              'into an extremely unique Spaghetti Western.',
#  'release_date': nan,
#  'title': 'Bad Chicken'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '52045',
#  'overview': nan,
#  'release_date': '2010-12-22',
#  'title': 'Libre échange'}
# Dropping:
# {'genres': '[]',
#  'id': '173433',
#  'overview': '94-year-old New Yorker, Jack Beers, has broken the age barrier '
#              'full force. He can do what most young men can, and his diverse '
#              'lifetime achievements would take many to accomplish. The film '
#              "begins with Mayor Bloomberg acknowledging Jack, we see Jack's "
#              'name on the marquee of Radio City Music Hall, and at 94 he rips '
#              'a telephone book into 4 pieces with his hands. Jack was raised '
#              'in poverty in Manhattan, was a strongman, built Radio City Music '
#              'Hall, at The Manhattan Project he invented something that '
#              'shortened WW2, erected the Empire State Building spire, was a '
#              'professional dog trainer, was a film actor in 200+ films, beat '
#              'terminal illnesses, and today rides 5 miles on a stationary '
#              'bike. He\'s "goin\' for 100!"',
#  'release_date': nan,
#  'title': 'Holes in My Shoes'}
# Dropping:
# {'genres': '[]',
#  'id': '430985',
#  'overview': nan,
#  'release_date': '1992-09-17',
#  'title': 'The Diamond Fleece'}
# Dropping:
# {'genres': '[]',
#  'id': '85469',
#  'overview': nan,
#  'release_date': '2012-04-12',
#  'title': 'Einer wie Bruno'}
# Dropping:
# {'genres': "[{'id': 9648, 'name': 'Mystery'}, {'id': 80, 'name': 'Crime'}, "
#            "{'id': 18, 'name': 'Drama'}]",
#  'id': '388182',
#  'overview': nan,
#  'release_date': '2013-08-07',
#  'title': 'هیچ کجا هیچ کس'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]",
#  'id': '130233',
#  'overview': nan,
#  'release_date': '2012-07-12',
#  'title': 'Fly Away'}
# Dropping:
# {'genres': '[]',
#  'id': '267219',
#  'overview': nan,
#  'release_date': '2008-01-01',
#  'title': 'Serrallonga'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '110992',
#  'overview': nan,
#  'release_date': '2007-08-08',
#  'title': "Summer of '62"}
# Dropping:
# {'genres': "[{'id': 53, 'name': 'Thriller'}, {'id': 10769, 'name': 'Foreign'}]",
#  'id': '81600',
#  'overview': nan,
#  'release_date': '2004-09-16',
#  'title': 'Stille Nacht'}
# Dropping:
# {'genres': "[{'id': 9648, 'name': 'Mystery'}, {'id': 80, 'name': 'Crime'}]",
#  'id': '91380',
#  'overview': nan,
#  'release_date': '1957-03-22',
#  'title': "Les aventures d'Arsène Lupin"}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '101352',
#  'overview': nan,
#  'release_date': '2012-03-21',
#  'title': "L'Antisémite"}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '297560',
#  'overview': nan,
#  'release_date': '1959-11-16',
#  'title': 'Το Ξύλο Βγήκε Από Τον Παράδεισο'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '331958',
#  'overview': nan,
#  'release_date': '1954-03-31',
#  'title': 'Λατέρνα, Φτώχεια και Γαρύφαλλο'}
# Dropping:
# {'genres': '[]',
#  'id': '52150',
#  'overview': nan,
#  'release_date': '2007-04-13',
#  'title': 'Zincirbozan'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]",
#  'id': '216369',
#  'overview': nan,
#  'release_date': '1997-12-26',
#  'title': 'Tentação'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '172890',
#  'overview': nan,
#  'release_date': '2012-03-01',
#  'title': 'Metastases'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 9648, 'name': 'Mystery'}]",
#  'id': '52147',
#  'overview': nan,
#  'release_date': '2008-02-25',
#  'title': 'Ulak'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '246320',
#  'overview': nan,
#  'release_date': '2014-02-12',
#  'title': 'The Three Brothers: The Return'}
# Dropping:
# {'genres': '[]',
#  'id': '158517',
#  'overview': "On her way home from an evening shift at a men's clothing store, "
#              'Saara Nevanen is raped by a man whom she recognizes as her '
#              'regular but eccentric customer, Antti Kaironen. The doctor and '
#              'policemen question Saara in an insensitive manner,and she breaks '
#              'down with guilt. When the court releases the perpetrator inlack '
#              "of evidence, Saara's aggressive brother Jari talks her "
#              'mild-mannered husband Sakari into a self-made revenge plot. '
#              'Armed with two rifles, Jari and Sakari take matters into their '
#              'own hands.',
#  'release_date': nan,
#  'title': 'Lain ulkopuolella'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '32547',
#  'overview': nan,
#  'release_date': '2004-03-18',
#  'title': 'Social Genocide'}
# Dropping:
# {'genres': "[{'id': 28, 'name': 'Action'}, {'id': 878, 'name': 'Science "
#            "Fiction'}]",
#  'id': '418029',
#  'overview': nan,
#  'release_date': '1967-07-21',
#  'title': 'Ultraman'}
# Dropping:
# {'genres': '[]',
#  'id': '142984',
#  'overview': nan,
#  'release_date': '1977-12-30',
#  'title': 'Scott Joplin'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '204765',
#  'overview': nan,
#  'release_date': '2014-01-21',
#  'title': 'Prêt à tout'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '68827',
#  'overview': nan,
#  'release_date': '1970-04-17',
#  'title': 'She Does Not Drink Smoke or Flirts but She Talks'}
# Dropping:
# {'genres': "[{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}, "
#            "{'id': 9648, 'name': 'Mystery'}]",
#  'id': '116894',
#  'overview': nan,
#  'release_date': '2001-04-23',
#  'title': 'Blind Terror'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10769, 'name': 'Foreign'}]",
#  'id': '55825',
#  'overview': nan,
#  'release_date': '2007-06-17',
#  'title': 'Spider'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '394403',
#  'overview': nan,
#  'release_date': '2014-03-21',
#  'title': 'Schwestern'}
# Dropping:
# {'genres': '[]',
#  'id': '202183',
#  'overview': nan,
#  'release_date': '2010-06-01',
#  'title': 'Ein Schnitzel für drei'}
# Dropping:
# {'genres': "[{'id': 10770, 'name': 'TV Movie'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '272543',
#  'overview': nan,
#  'release_date': '2014-05-23',
#  'title': 'Die Fischerin'}
# Dropping:
# {'genres': '[]',
#  'id': '173151',
#  'overview': nan,
#  'release_date': '2004-10-29',
#  'title': 'El chocolate del loro'}
# Dropping:
# {'genres': "[{'id': 27, 'name': 'Horror'}]",
#  'id': '206574',
#  'overview': nan,
#  'release_date': '2011-02-26',
#  'title': 'Unrated II: Scary as Hell'}
# Dropping:
# {'genres': "[{'id': 9648, 'name': 'Mystery'}, {'id': 35, 'name': 'Comedy'}]",
#  'id': '60106',
#  'overview': nan,
#  'release_date': '2004-06-23',
#  'title': 'Loser Takes All!'}
# Dropping:
# {'genres': '[]',
#  'id': '164419',
#  'overview': nan,
#  'release_date': '2009-01-23',
#  'title': 'Maata meren alla'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '44155',
#  'overview': nan,
#  'release_date': '2010-07-07',
#  'title': 'The Italian'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '64934',
#  'overview': nan,
#  'release_date': '2002-06-26',
#  'title': 'Le Nouveau Jean-Claude'}
# Dropping:
# {'genres': "[{'id': 10402, 'name': 'Music'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '74950',
#  'overview': nan,
#  'release_date': '2007-01-18',
#  'title': 'Breakout'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '2692',
#  'overview': nan,
#  'release_date': '2007-02-13',
#  'title': 'The Red Elvis'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '76846',
#  'overview': nan,
#  'release_date': '1975-06-25',
#  'title': 'A Guy and a Gal'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '173300',
#  'overview': "What happens when America's most joyous, dysfunctional city "
#              'rebuilds itself after a disaster? New Orleans is the setting for '
#              'Getting Back to Abnormal, a film that serves up a provocative '
#              'mix of race, corruption and politics to tell the story of the '
#              're-election campaign of Stacy Head, a white woman in a city '
#              'council seat traditionally held by a black representative. '
#              'Supported by her irrepressible African-American aide Barbara '
#              'Lacen-Keller, Head polarizes the city as her candidacy threatens '
#              'to diminish the power and influence of its black citizens. '
#              'Featuring a cast of characters as colorful as the city itself, '
#              'the film presents a New Orleans that outsiders rarely see.',
#  'release_date': nan,
#  'title': 'Getting Back to Abnormal'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '329227',
#  'overview': nan,
#  'release_date': '2014-03-05',
#  'title': 'Mi Amigo Hugo'}
# Dropping:
# {'genres': "[{'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}]",
#  'id': '343693',
#  'overview': nan,
#  'release_date': '2008-08-12',
#  'title': 'Aladin'}
# Dropping:
# {'genres': '[]',
#  'id': '287831',
#  'overview': 'Harry Raymond, a foreign ambassador in Moscow, is at the '
#              'pinnacle of a distinguished career when he is implicated in the '
#              'savage murder of a young Russian artist. Stars Henry Czerny, '
#              'Victor Garber.',
#  'release_date': nan,
#  'title': 'External Affairs'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}]",
#  'id': '182799',
#  'overview': nan,
#  'release_date': '2000-04-03',
#  'title': 'Cement'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '230295',
#  'overview': nan,
#  'release_date': '2000-08-31',
#  'title': 'Hur som helst är han jävligt död'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '42416',
#  'overview': nan,
#  'release_date': '1984-01-01',
#  'title': 'Arrapaho'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]",
#  'id': '273510',
#  'overview': nan,
#  'release_date': '2000-06-02',
#  'title': 'Madame Bovary'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '12076',
#  'overview': nan,
#  'release_date': '2005-09-23',
#  'title': 'Elsk meg i morgen'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '127375',
#  'overview': 'Welcome to the modest small town of Bucks County, Pennsylvania. '
#              'Enjoy your stay at Bucksville house and have your room tidied up '
#              'in the morning by colonial maids who turn and vanish. At the '
#              'Wedgewood Inn, explore a tunnel of the Underground Railroad '
#              'where slaves passed through to freedom and the spirits of some '
#              'still linger. Examine the mystery of the figure on horseback, '
#              'spotted in the woods outside the Arianna Miles, as this '
#              'fascinating documentary reveals some of the most amazing images '
#              'of spirits ever recorded!',
#  'release_date': nan,
#  'title': "America's Most Haunted Inns"}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '204768',
#  'overview': nan,
#  'release_date': '2013-09-18',
#  'title': 'Les invincibles'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '117678',
#  'overview': nan,
#  'release_date': '2011-10-27',
#  'title': "Dans la peau d'une grande"}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '198130',
#  'overview': nan,
# ...
#              'life, the search for life on Mars, the infernal composition of '
#              'the atmosphere of Venus and a warning about a similar effect '
#              'taking place on Earth due to global pollution and the '
#              '"greenhouse effect", the lives of stars, interstellar travel and '
#              'the effects of attaining the speed of light, the danger of '
#              'mankind technologically self-destructing, and the search, using '
#              'radio technology, for intelligent life in deep space.',
#  'release_date': nan,
#  'title': 'Cosmos'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '453596',
#  'overview': nan,
#  'release_date': '2017-04-20',
#  'title': 'Kolonya Cumhuriyeti'}
# Dropping:
# {'genres': "[{'id': 12, 'name': 'Adventure'}, {'id': 27, 'name': 'Horror'}, "
#            "{'id': 9648, 'name': 'Mystery'}]",
#  'id': '142802',
#  'overview': nan,
#  'release_date': '1992-01-01',
#  'title': 'Гонгофер'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '439998',
#  'overview': nan,
#  'release_date': '2017-03-02',
#  'title': "Omicidio all'italiana"}
# Dropping:
# {'genres': "[{'id': 10770, 'name': 'TV Movie'}]",
#  'id': '143883',
#  'overview': nan,
#  'release_date': '2001-03-24',
#  'title': 'Den radio'}
# Dropping:
# {'genres': "[{'id': 27, 'name': 'Horror'}]",
#  'id': '354133',
#  'overview': nan,
#  'release_date': '2006-06-06',
#  'title': 'Zombeak'}
# Dropping:
# {'genres': '[]',
#  'id': '191486',
#  'overview': nan,
#  'release_date': '1986-05-12',
#  'title': 'Поезд вне расписания'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '127803',
#  'overview': nan,
#  'release_date': '2011-01-01',
#  'title': '3 Times a Charm'}
# Dropping:
# {'genres': '[]',
#  'id': '271495',
#  'overview': nan,
#  'release_date': '2014-04-24',
#  'title': 'Dialogues'}
# Dropping:
# {'genres': "[{'id': 16, 'name': 'Animation'}]",
#  'id': '244575',
#  'overview': nan,
#  'release_date': '1970-12-19',
#  'title': 'Кентервильское привидение'}
# Dropping:
# {'genres': '[]',
#  'id': '246438',
#  'overview': nan,
#  'release_date': '2007-02-07',
#  'title': 'Семь кабинок'}
# Dropping:
# {'genres': '[]',
#  'id': '400796',
#  'overview': 'Professor Irwin Corey is now 101 years old and he is a well '
#              'known comedian, entertainer and political satirist. Fran is 95 '
#              "and his wife of 71 years. Dick Gregory shares Irwin's "
#              'contribution and family friend Susan Sarandon narrates.',
#  'release_date': nan,
#  'title': 'Irwin & Fran 2013'}
# Dropping:
# {'genres': "[{'id': 10752, 'name': 'War'}, {'id': 35, 'name': 'Comedy'}]",
#  'id': '36264',
#  'overview': nan,
#  'release_date': '1986-09-22',
#  'title': 'The Deserters'}
# Dropping:
# {'genres': '[]',
#  'id': '270908',
#  'overview': nan,
#  'release_date': '1961-10-17',
#  'title': 'Совершенно серьезно'}
# Dropping:
# {'genres': "[{'id': 878, 'name': 'Science Fiction'}]",
#  'id': '14210',
#  'overview': nan,
#  'release_date': '2007-01-01',
#  'title': 'Nightmare City 2035'}
# Dropping:
# {'genres': '[]',
#  'id': '441826',
#  'overview': "Natalia Brożyńska's animation debut, about dramatic love, "
#              'acceptance and happy endings.',
#  'release_date': nan,
#  'title': 'Shivering Trunks'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '376934',
#  'overview': nan,
#  'release_date': '2005-01-10',
#  'title': 'Restart'}
# Dropping:
# {'genres': "[{'id': 16, 'name': 'Animation'}]",
#  'id': '213321',
#  'overview': nan,
#  'release_date': '1986-01-01',
#  'title': 'Investigation Held by Kolobki'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '380438',
#  'overview': nan,
#  'release_date': '2001-01-01',
#  'title': "Lettre d'une inconnue"}
# Dropping:
# {'genres': "[{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}]",
#  'id': '41493',
#  'overview': nan,
#  'release_date': '2002-09-27',
#  'title': 'Karlsson on the Roof'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '452922',
#  'overview': nan,
#  'release_date': nan,
#  'title': 'Supermassive Black Holes'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '93461',
#  'overview': nan,
#  'release_date': '2001-12-26',
#  'title': 'Sexy boys'}
# Dropping:
# {'genres': '[]',
#  'id': '340155',
#  'overview': 'Inhabitants of an elite Moscow house get involved in a game of a '
#              "terrorist threatening to kill them one by one if they don't pay "
#              'them a large amount of money.',
#  'release_date': nan,
#  'title': 'Игра на выбывание'}
# Dropping:
# {'genres': "[{'id': 28, 'name': 'Action'}, {'id': 10749, 'name': 'Romance'}, "
#            "{'id': 53, 'name': 'Thriller'}, {'id': 878, 'name': 'Science "
#            "Fiction'}]",
#  'id': '63838',
#  'overview': nan,
#  'release_date': '2006-10-12',
#  'title': 'Mechenosets'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]",
#  'id': '197057',
#  'overview': nan,
#  'release_date': '2003-12-04',
#  'title': 'А поутру они проснулись'}
# Dropping:
# {'genres': "[{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '336484',
#  'overview': nan,
#  'release_date': '2008-09-18',
#  'title': 'Каменная башка'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}]",
#  'id': '159810',
#  'overview': nan,
#  'release_date': '2007-07-03',
#  'title': 'Caravaggio'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}, "
#            "{'id': 10752, 'name': 'War'}]",
#  'id': '51275',
#  'overview': nan,
#  'release_date': '2009-04-04',
#  'title': 'The Priest'}
# Dropping:
# {'genres': "[{'id': 10749, 'name': 'Romance'}]",
#  'id': '420481',
#  'overview': nan,
#  'release_date': '2010-04-10',
#  'title': 'Путь к себе'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}]",
#  'id': '26792',
#  'overview': nan,
#  'release_date': '2006-02-12',
#  'title': 'The Storm Gate'}
# Dropping:
# {'genres': "[{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'name': 'Drama'}]",
#  'id': '48209',
#  'overview': nan,
#  'release_date': '1961-01-01',
#  'title': 'Hamlet, Prince of Denmark'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '456956',
#  'overview': 'A white author is sucked into a road trip through the heart on '
#              'Native American Country by a Lakota elder and his best friend '
#              'forcing the author into a deep understanding of contemporary '
#              'native life.',
#  'release_date': nan,
#  'title': 'Neither Wolf Nor Dog'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '57382',
#  'overview': nan,
#  'release_date': '2011-02-16',
#  'title': "Halal Police d'Etat"}
# Dropping:
# {'genres': "[{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}, "
#            "{'id': 36, 'name': 'History'}]",
#  'id': '110131',
#  'overview': nan,
#  'release_date': '1962-12-13',
#  'title': 'The Man of Gold'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '41689',
#  'overview': nan,
#  'release_date': '1978-01-01',
#  'title': 'Abigél'}
# Dropping:
# {'genres': "[{'id': 99, 'name': 'Documentary'}]",
#  'id': '458808',
#  'overview': nan,
#  'release_date': '2015-06-04',
#  'title': 'Nice Places to Die'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '400552',
#  'overview': nan,
#  'release_date': '2017-04-11',
#  'title': 'Happy Burnout'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '419601',
#  'overview': nan,
#  'release_date': '1979-07-06',
#  'title': 'Поэма о крыльях'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '14644',
#  'overview': nan,
#  'release_date': '2005-03-09',
#  'title': 'Boudu'}
# Dropping:
# {'genres': "[{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, "
#            "{'id': 878, 'name': 'Science Fiction'}, {'id': 10769, 'name': "
#            "'Foreign'}]",
#  'id': '82495',
#  'overview': nan,
#  'release_date': '2001-03-21',
#  'title': 'Gamer'}
# Dropping:
# {'genres': '[]',
#  'id': '64827',
#  'overview': nan,
#  'release_date': '2005-01-01',
#  'title': "L'educazione sentimentale di Eugenie"}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '103301',
#  'overview': nan,
#  'release_date': '1990-02-01',
#  'title': 'Babnik'}
# Dropping:
# {'genres': "[{'id': 878, 'name': 'Science Fiction'}, {'id': 53, 'name': "
#            "'Thriller'}]",
#  'id': '301876',
#  'overview': nan,
#  'release_date': '1998-01-01',
#  'title': '30 Years to Life'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '73545',
#  'overview': nan,
#  'release_date': '1972-08-19',
#  'title': 'Ехали в трамвае Ильф и Петров'}
# Dropping:
# {'genres': "[{'id': 16, 'name': 'Animation'}]",
#  'id': '448879',
#  'overview': nan,
#  'release_date': '1986-03-25',
#  'title': 'Приключения Домовёнка'}
# Dropping:
# {'genres': "[{'id': 9648, 'name': 'Mystery'}, {'id': 99, 'name': "
#            "'Documentary'}]",
#  'id': '457307',
#  'overview': nan,
#  'release_date': '2017-03-02',
#  'title': 'Don\'t call him "Dimon"'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '396987',
#  'overview': nan,
#  'release_date': '1938-06-11',
#  'title': 'Медведь'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '153561',
#  'overview': nan,
#  'release_date': '2008-11-14',
#  'title': 'La buena nueva'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '366860',
#  'overview': nan,
#  'release_date': '1960-11-24',
#  'title': 'El Violetero'}
# Dropping:
# {'genres': "[{'id': 27, 'name': 'Horror'}]",
#  'id': '202865',
#  'overview': nan,
#  'release_date': '2011-06-21',
#  'title': 'The Gerber Syndrome: Il Contagio'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '9765',
#  'overview': nan,
#  'release_date': '1999-10-06',
#  'title': 'Der große Bagarozy'}
# Dropping:
# {'genres': "[{'id': 10749, 'name': 'Romance'}]",
#  'id': '213683',
#  'overview': nan,
#  'release_date': '1998-12-30',
#  'title': 'Перекресток'}
# Dropping:
# {'genres': "[{'id': 16, 'name': 'Animation'}, {'id': 27, 'name': 'Horror'}, "
#            "{'id': 878, 'name': 'Science Fiction'}]",
#  'id': '425916',
#  'overview': 'The adventures of Salad Fingers, an unspecified mutated creature '
#              'driven to madness by his loneliness.',
#  'release_date': nan,
#  'title': 'Salad Fingers'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '142320',
#  'overview': nan,
#  'release_date': '2012-10-25',
#  'title': "Viva l'Italia"}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '430058',
#  'overview': nan,
#  'release_date': '2016-12-16',
#  'title': 'Votez Bougon'}
# Dropping:
# {'genres': '[]',
#  'id': '54309',
#  'overview': nan,
#  'release_date': '2007-02-14',
#  'title': 'Notte prima degli esami - Oggi'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '445840',
#  'overview': nan,
#  'release_date': '2017-06-23',
#  'title': 'Selfie'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '64043',
#  'overview': nan,
#  'release_date': '1947-01-01',
#  'title': 'I due orfanelli'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '73649',
#  'overview': nan,
#  'release_date': '1999-12-17',
#  'title': 'Tutti gli uomini del deficiente'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '57996',
#  'overview': nan,
#  'release_date': '1953-09-16',
#  'title': 'Neapolitan Turk'}
# Dropping:
# {'genres': '[]',
#  'id': '398295',
#  'overview': nan,
#  'release_date': nan,
#  'title': 'Mundo Cão'}
# Dropping:
# {'genres': "[{'id': 12, 'name': 'Adventure'}, {'id': 36, 'name': 'History'}]",
#  'id': '353713',
#  'overview': nan,
#  'release_date': '1947-09-29',
#  'title': 'La nao Capitana'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '458335',
#  'overview': nan,
#  'release_date': '2017-07-06',
#  'title': 'Soundtrack'}
# Dropping:
# {'genres': '[]',
#  'id': '298207',
#  'overview': nan,
#  'release_date': '2010-11-18',
#  'title': 'Der kleine Nazi'}
# Dropping:
# {'genres': "[{'id': 10751, 'name': 'Family'}, {'id': 35, 'name': 'Comedy'}]",
#  'id': '382995',
#  'overview': nan,
#  'release_date': '1972-06-03',
#  'title': 'George !'}
# Dropping:
# {'genres': '[]',
#  'id': '439314',
#  'overview': "Brazilian philosopher Olavo de Carvalho's thinking, presented "
#              'through his presence, his daily work routine and his family life '
#              'in Virginia (USA).',
#  'release_date': nan,
#  'title': 'The Garden of Afflictions 2017'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]",
#  'id': '422005',
#  'overview': nan,
#  'release_date': '2016-10-19',
#  'title': 'Tatu and Patu'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '26969',
#  'overview': nan,
#  'release_date': '2008-04-18',
#  'title': '8 Dates'}
# Dropping:
# {'genres': "[{'id': 16, 'name': 'Animation'}]",
#  'id': '91673',
#  'overview': nan,
#  'release_date': '1984-01-01',
#  'title': 'Wolf and Calf'}
# Dropping:
# {'genres': '[]',
#  'id': '438910',
#  'overview': 'Engineering Red - 1993  Dir: Andrey I. Y. Petrosyan  '
#              'Medical/art/found footage collage.',
#  'release_date': nan,
#  'title': 'Engineering Red'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '68063',
#  'overview': nan,
#  'release_date': '2008-03-19',
#  'title': 'Questa notte è ancora nostra'}
# Dropping:
# {'genres': "[{'id': 9648, 'name': 'Mystery'}, {'id': 878, 'name': 'Science "
#            "Fiction'}]",
#  'id': '433711',
#  'overview': 'In a no holds barred documentary, acclaimed journalist Vicky '
#              "O'Neil sets out on a quest to uncover the truth behind the "
#              'murder of small town sweetheart Ally Andrews. What she uncovers, '
#              'leads her down a dark and twisted rabbit hole into the world of '
#              'superheroes where she gets the chance of a lifetime, an '
#              "exclusive interview with Charge, the world's Last Superhero. As "
#              'he chronicles his mysterious origins and bloody career, Vicky '
#              'begins to wonder, is he still the hero the world remembers, or '
#              'has he become the villain we all should fear?',
#  'release_date': nan,
#  'title': 'All Superheroes Must Die 2: The Last Superhero'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '103344',
#  'overview': nan,
#  'release_date': '2012-04-30',
#  'title': 'Dépression et des Potes'}
# Dropping:
# {'genres': "[{'id': 35, 'name': 'Comedy'}]",
#  'id': '231216',
#  'overview': nan,
#  'release_date': '2004-12-02',
#  'title': 'Villa Henriette'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '79343',
#  'overview': nan,
#  'release_date': '2007-11-14',
#  'title': 'Les fourmis rouges'}
# Dropping:
# {'genres': '[]',
#  'id': '418757',
#  'overview': nan,
#  'release_date': '2014-08-01',
#  'title': 'Między nami dobrze jest'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}]",
#  'id': '369444',
#  'overview': nan,
#  'release_date': '1989-10-27',
#  'title': 'Ostatni dzwonek'}
# Dropping:
# {'genres': '[]',
#  'id': '335251',
#  'overview': 'An exploration of the musical and social origins of the blues, '
#              'shot on location in Mississippi in 1978 by Alan Lomax, John '
#              'Bishop, and Worth Long in association with the Mississippi '
#              'Authority for Educational Television and broadcast on PBS in '
#              '1980. This re-release in 2009 includes two hours of additional '
#              'music.',
#  'release_date': nan,
#  'title': 'The Land Where the Blues Began'}
# Dropping:
# {'genres': "[{'id': 53, 'name': 'Thriller'}]",
#  'id': '395767',
#  'overview': nan,
#  'release_date': '2017-01-11',
#  'title': 'Scribe'}
# Dropping:
# {'genres': "[{'id': 12, 'name': 'Adventure'}]",
#  'id': '317389',
#  'overview': nan,
#  'release_date': '1973-07-22',
#  'title': 'Simbad e il califfo di Bagdad'}
# Dropping:
# {'genres': "[{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]",
#  'id': '468707',
#  'overview': nan,
#  'release_date': '2017-07-28',
#  'title': 'Thick Lashes of Lauri Mäntyvaara'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}]",
#  'id': '449131',
#  'overview': nan,
#  'release_date': nan,
#  'title': 'Aprel'}
# Dropping:
# {'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}]",
#  'id': '439050',
#  'overview': 'Rising and falling between a man and woman.',
#  'release_date': nan,
#  'title': 'Subdue'}
# Done importing movies into redis.

# %% [markdown]
# See how many movies you have left, and make sure you can retrieve a movie by ID. 862 is the id for Toy Story. You should see some metadata for that film if you retrieve that key.

# %%
print(len(movies_dict))
data = redis_server.get("862")
movie = json.loads(data)
print(movie)
# Out:
# 44535
# {'id': '862', 'title': 'Toy Story', 'overview': "Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.", 'release_date': '1995-10-30', 'genres': "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"}

# %% [markdown]
# So, with the meta data stored in Redis, it's time to calculate the embeddings and add them to Milvus.
#
# First, you need a collection to store them in. Create a simple one that stores the movie ID and embeddings for in the **Movies** field.
#
# Then, you'll index that field to make searches more efficent.

# %%
COLLECTION_NAME = 'film_vectors'
PARTITION_NAME = 'Movie'

pk = FieldSchema(name='ID', dtype=DataType.INT64, is_primary=True, auto_id=False)
field = FieldSchema(name='Movies', dtype=DataType.FLOAT_VECTOR, dim=384)
schema = CollectionSchema(fields=[pk, field], description="movie recommender: film vectors")

if utility.has_collection(COLLECTION_NAME): # drop the same collection created before
    collection = Collection(COLLECTION_NAME)
    collection.drop()
    
collection = Collection(name=COLLECTION_NAME, schema=schema)
print("Collection created.")

index_params = {
    "index_type": "IVF_FLAT",
    "metric_type": "L2",
    "params": {"nlist": 128},
}

collection.create_index(field_name="Movies", index_params=index_params)
collection.load()

print("Collection indexed!")
# Out:
# Collection created.
# alloc_timestamp unimplemented, ignore it
# Collection indexed!

# %% [markdown]
# Now, you need a function to create the embeddings.
#
# The primary artifact for movie information is the overview, but including the genre and release date in complete sentences may help with search accuracy.
#
# Create a transformer and call it from a simple function:
# - extract the id field
# - creates an embed from the overview, genre and release date
# - inserts the vector into Milvus.
#
# You'll reuse the **build_genres** function below for searching.

# %%
from sentence_transformers import SentenceTransformer
import ast

def build_genres(data):
    genres = data['genres']
    genre_list = ""
    entries= ast.literal_eval(genres)
    genres = ""
    for entry in entries:
        genre_list = genre_list + entry["name"] + ", "
    genres += genre_list
    genres = "".join(genres.rsplit(",", 1))
    return genres

transformer = SentenceTransformer('all-MiniLM-L6-v2')

def embed_movie(data):
    embed = "{} Released on {}. Genres are {}.".format(data["overview"], data["release_date"], build_genres(data))    
    embeddings = transformer.encode(embed)
    return embeddings

# %% [markdown]
# Now, you can create the embeddings. This dataset is too large to send to Milvus in a single insert statement, but sending them one at a time would create unnecessary network traffic and add too much time. So, this code uses batches. You can play with the batch size to suit your individual needs and preferences.
#
# A few movies will fail for ids that cannot be cast to integers. You could fix this above with a schema change or by verifying their format.

# %%
# Parallel arrays for movies ids and embeddings
ids = []
embeds = []

# Loop counter for batching and showing progress
j = 0

for movie_dict in movies_dict:
    try:
        ids.append(int(movie_dict["id"]))
        embeds.append(embed_movie(movie_dict))
        j += 1
        if j % 5000 == 0:
            print("Embedded {} records".format(j))
            data = [ids, embeds]
            collection.insert(data)
            print("Batch insert completed")
            ids = []
            embeds = []
    except ValueError as ve:
        print("Invalid id: {} for record {}".format(movie_dict["id"], j))

data = [ids, embeds]
collection.insert(data)
print("Final batch completed")
print("Finished with {} embeddings".format(j))
# Out:
# Embedded 5000 records
# Batch insert completed
# Embedded 10000 records
# Batch insert completed
# Embedded 15000 records
# Batch insert completed
# Invalid id: 1997-08-20 for record 19595
# Embedded 20000 records
# Batch insert completed
# Embedded 25000 records
# Batch insert completed
# Invalid id: 2012-09-29 for record 29175
# Embedded 30000 records
# Batch insert completed
# Embedded 35000 records
# Batch insert completed
# Invalid id: 2014-01-01 for record 35039
# Embedded 40000 records
# Batch insert completed
# Final batch completed
# Finished with 44532 embeddings

# %% [markdown]
# Now you can search for movies that match viewer criteria. To do this, you need a few more functions.
#
# First, you need a transformer to convert the user's search string to an embedding. For this, **embed_search** takes their criteria and passed it to the same transformer you used to populate Milvus.
#
# Milvus will return a set of movie ids. You need to use them to retrieve data about those ids from Redis. This happens in **collate_results**.
#
# Finally, **search_for_movies** performs the actual vector search, using the other two functions for support.

# %%
collection.load() # load collection memory before search

# Set search parameters
topK = 5
SEARCH_PARAM = {
    "metric_type":"L2",
    "params":{"nprobe": 20},
}


def embed_search(search_string):
    search_embeddings = transformer.encode(search_string)
    return search_embeddings


def collate_results(ids):
    movies = []    
    for id in ids:
        data = redis_server.get(str(id))
        if data:
            movie = json.loads(data)
            genres = build_genres(movie)
            movie["genres"] = genres
            movies.append(movie)
    return movies


def search_for_movies(search_string):
    user_vector = embed_search(search_string)
    results = collection.search([user_vector],"Movies",param=SEARCH_PARAM, limit=topK, expr=None, output_fields=None)
    return collate_results(results[0].ids)

# %% [markdown]
# So, put this search to work!
#
# This search is looking for 1990s comedies with Vampires. The first hit is exactly that, but as the vector distance increases you can see that the films move further away from what you're looking for.
#
# You can play around with different search criteria.

# %%
from pprint import pprint


search_string = "A comedy from the 1990s set in a hospital. The main characters are in their 20s and are trying to stop a vampire."
results = search_for_movies(search_string)
pprint(results)
# Out:
# [{'genres': 'Thriller, Comedy ',
#   'id': '281289',
#   'overview': 'A sarcastic comedy thriller about a vampire who sets out to '
#               'infect the blood of a hospital and the twenty-something '
#               'slackers who set out to stop him.',
#   'release_date': '1998-05-18',
#   'title': 'Tainted'},
#  {'genres': 'Comedy, Horror ',
#   'id': '65416',
#   'overview': 'A group of friends go on a vacation with some new friends that '
#               'turn out to be vampires, they hire a famous vampire killer to '
#               'help them.',
#   'release_date': '1997-01-24',
#   'title': 'An American Vampire Story'},
#  {'genres': 'Horror, Science Fiction ',
#   'id': '40028',
#   'overview': 'A science fiction vampire movie. The Vampire is an emissary '
#               'from an embattled world near destruction who teleports to Earth '
#               'to see if they can live here. He finds that our blood is '
#               'nourishing and that at least one source of it is a steady '
#               'stream of transfusions. He hypnotizes a Dr. to provide them and '
#               'has his blond nurse move in to administer them.',
#   'release_date': '1988-05-20',
#   'title': 'Not of This Earth'},
#  {'genres': 'Comedy ',
#   'id': '56549',
#   'overview': 'A comedy about a New Year Eve celebration in one very funny '
#               'hospital.',
#   'release_date': '1996-01-01',
#   'title': "Operation 'Happy New Year'!"},
#  {'genres': 'Thriller, Comedy ',
#   'id': '85968',
#   'overview': 'Young, sexy nurses and their hospital adventures.',
#   'release_date': '1974-05-01',
#   'title': 'Candy Stripe Nurses'}]
