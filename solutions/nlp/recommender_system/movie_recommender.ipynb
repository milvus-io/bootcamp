# %% [markdown]
# # Recommender System

# %% [markdown]
# In this example we are creating a movie recommender system by extracting feature vectors using SentenceTransformers, importing movie vectors into Milvus, metadata into Redis, searching in Milvus, and providing searchers movie data from Redis.

# %% [markdown]
# ## Data
#
# This is wrong.
#
# In this project, we use [MovieLens 1M](https://grouplens.org/datasets/movielens/1m/). This dataset contains 1,000,209 anonymous ratings of approximately 3,900 movies made by 6,040 MovieLens users.
#
# We use the following files:
# - movies.dat: Contains movie information.
# - movie_vectors.txt: Contains movie vectors that can be imported to Milvus easily.
#
# File structure:
#
#  - movMovieID::Title::Genres
#
#      - Titles are identical to titles provided by the IMDB (includingyear of release)
#
#      - Genres are pipe-separated
#
#      - Some MovieIDs do not correspond to a movie due to accidental duplicate entries and/or test entries
#
#     - Movies are mostly entered by hand, so errors and inconsistencies may exist

# %% [markdown]
# # Requirements
#
# bla bla bla

# %%
! python -m pip install pymilvus redis pandas sentence_transformers
# Out:
# Requirement already satisfied: pymilvus in ./movies_venv/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: redis in ./movies_venv/lib/python3.10/site-packages (5.0.0)
# Requirement already satisfied: pandas in ./movies_venv/lib/python3.10/site-packages (2.0.3)
# Collecting sentence_transformers
#   Using cached sentence-transformers-2.2.2.tar.gz (85 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: grpcio<=1.56.0,>=1.49.1 in ./movies_venv/lib/python3.10/site-packages (from pymilvus) (1.56.0)
# Requirement already satisfied: protobuf>=3.20.0 in ./movies_venv/lib/python3.10/site-packages (from pymilvus) (4.24.1)
# Requirement already satisfied: environs<=9.5.0 in ./movies_venv/lib/python3.10/site-packages (from pymilvus) (9.5.0)
# Requirement already satisfied: ujson>=2.0.0 in ./movies_venv/lib/python3.10/site-packages (from pymilvus) (5.8.0)
# Requirement already satisfied: async-timeout>=4.0.2 in ./movies_venv/lib/python3.10/site-packages (from redis) (4.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./movies_venv/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./movies_venv/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./movies_venv/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in ./movies_venv/lib/python3.10/site-packages (from pandas) (1.25.2)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence_transformers)
#   Obtaining dependency information for transformers<5.0.0,>=4.6.0 from https://files.pythonhosted.org/packages/1a/06/3817f9bb923437ead9a794f0ac0d03b8b5e0478ab112db4c413dd37c09da/transformers-4.33.2-py3-none-any.whl.metadata
#   Downloading transformers-4.33.2-py3-none-any.whl.metadata (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 7.0 MB/s eta 0:00:00
# Collecting tqdm (from sentence_transformers)
#   Obtaining dependency information for tqdm from https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl.metadata
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Collecting torch>=1.6.0 (from sentence_transformers)
#   Downloading torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 7.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting torchvision (from sentence_transformers)
#   Downloading torchvision-0.15.2-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 50.0 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting scikit-learn (from sentence_transformers)
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/7d/af/03d3a7d5719d00486c296ddd876e6f07a681bc4e079cb45348d2f261a748/scikit_learn-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading scikit_learn-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting scipy (from sentence_transformers)
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/a8/cc/c36f3439f5d47c3b13833ce6687b43a040cc7638c502ac46b41e2d4f3d6f/scipy-1.11.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading scipy-1.11.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 4.2 MB/s eta 0:00:00
# Collecting nltk (from sentence_transformers)
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: sentencepiece in ./movies_venv/lib/python3.10/site-packages (from sentence_transformers) (0.1.96)
# Collecting huggingface-hub>=0.4.0 (from sentence_transformers)
#   Obtaining dependency information for huggingface-hub>=0.4.0 from https://files.pythonhosted.org/packages/72/21/51cddb8850ed3f4dbc21e57c3dabc49e64d5577857ddda7b2eb0ffc2ec0e/huggingface_hub-0.17.2-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.17.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: marshmallow>=3.0.0 in ./movies_venv/lib/python3.10/site-packages (from environs<=9.5.0->pymilvus) (3.20.1)
# Requirement already satisfied: python-dotenv in ./movies_venv/lib/python3.10/site-packages (from environs<=9.5.0->pymilvus) (1.0.0)
# Collecting filelock (from huggingface-hub>=0.4.0->sentence_transformers)
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/5e/5d/97afbafd9d584ff1b45fcb354a479a3609bd97f912f8f1f6c563cb1fae21/filelock-3.12.4-py3-none-any.whl.metadata
#   Downloading filelock-3.12.4-py3-none-any.whl.metadata (2.8 kB)
# Collecting fsspec (from huggingface-hub>=0.4.0->sentence_transformers)
#   Obtaining dependency information for fsspec from https://files.pythonhosted.org/packages/6a/af/c673e8c663e17bd4fb201a6f029153ad5d7023aa4442d81c7987743db379/fsspec-2023.9.1-py3-none-any.whl.metadata
#   Downloading fsspec-2023.9.1-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: requests in ./movies_venv/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in ./movies_venv/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./movies_venv/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in ./movies_venv/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: six>=1.5 in ./movies_venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting sympy (from torch>=1.6.0->sentence_transformers)
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch>=1.6.0->sentence_transformers)
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: jinja2 in ./movies_venv/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch>=1.6.0->sentence_transformers)
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch>=1.6.0->sentence_transformers)
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch>=1.6.0->sentence_transformers)
#   Using cached nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch>=1.6.0->sentence_transformers)
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch>=1.6.0->sentence_transformers)
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch>=1.6.0->sentence_transformers)
#   Using cached nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch>=1.6.0->sentence_transformers)
#   Using cached nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch>=1.6.0->sentence_transformers)
#   Using cached nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch>=1.6.0->sentence_transformers)
#   Using cached nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
# Collecting nvidia-nccl-cu11==2.14.3 (from torch>=1.6.0->sentence_transformers)
#   Using cached nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch>=1.6.0->sentence_transformers)
#   Using cached nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Collecting triton==2.0.0 (from torch>=1.6.0->sentence_transformers)
#   Downloading triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 35.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: setuptools in ./movies_venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence_transformers) (65.5.1)
# Collecting wheel (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence_transformers)
#   Obtaining dependency information for wheel from https://files.pythonhosted.org/packages/b8/8b/31273bf66016be6ad22bb7345c37ff350276cfd46e389a0c2ac5da9d9073/wheel-0.41.2-py3-none-any.whl.metadata
#   Using cached wheel-0.41.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting cmake (from triton==2.0.0->torch>=1.6.0->sentence_transformers)
#   Obtaining dependency information for cmake from https://files.pythonhosted.org/packages/de/94/cba4b3ddc0d4555967cce8fd6e9fbced98a6bf62857db71c2400a7b6e183/cmake-3.27.5-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Downloading cmake-3.27.5-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.7 kB)
# Collecting lit (from triton==2.0.0->torch>=1.6.0->sentence_transformers)
#   Using cached lit-16.0.6.tar.gz (153 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.6.0->sentence_transformers)
#   Obtaining dependency information for regex!=2019.12.17 from https://files.pythonhosted.org/packages/d1/df/460ca6171a8494fcf37af43f52f6fac23e38784bb4a26563f6fa01ef6faf/regex-2023.8.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading regex-2023.8.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 12.6 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence_transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 64.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence_transformers)
#   Obtaining dependency information for safetensors>=0.3.1 from https://files.pythonhosted.org/packages/6c/f0/c17bbdb1e5f9dab29d44cade445135789f75f8f08ea2728d04493ea8412b/safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: click in ./movies_venv/lib/python3.10/site-packages (from nltk->sentence_transformers) (8.1.7)
# Collecting joblib (from nltk->sentence_transformers)
#   Obtaining dependency information for joblib from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->sentence_transformers)
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./movies_venv/lib/python3.10/site-packages (from torchvision->sentence_transformers) (10.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./movies_venv/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./movies_venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in ./movies_venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./movies_venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./movies_venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.7.22)
# Collecting mpmath>=0.19 (from sympy->torch>=1.6.0->sentence_transformers)
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading huggingface_hub-0.17.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 70.5 MB/s eta 0:00:00
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 66.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading scikit_learn-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 65.5 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# Downloading scipy-1.11.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 41.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Downloading regex-2023.8.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (771 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 771.9/771.9 kB 73.8 MB/s eta 0:00:00
# Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.2 MB/s eta 0:00:00
# Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Downloading filelock-3.12.4-py3-none-any.whl (11 kB)
# Downloading fsspec-2023.9.1-py3-none-any.whl (173 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.4/173.4 kB 62.5 MB/s eta 0:00:00
# Downloading cmake-3.27.5-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (26.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.1/26.1 MB 48.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached wheel-0.41.2-py3-none-any.whl (64 kB)
# Building wheels for collected packages: sentence_transformers, lit
#   Building wheel for sentence_transformers (pyproject.toml) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=0899f2c1774a9e322a0788873df26c9d32097ca6427f3f7a596f6b418966bc32
#   Stored in directory: /home/egoebelbecker/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for lit (pyproject.toml) ... done
#   Created wheel for lit: filename=lit-16.0.6-py3-none-any.whl size=93584 sha256=bd0ff1fe1ef4c590850047be750befac20ea9dd17695fce22e480bde867cad9b
#   Stored in directory: /home/egoebelbecker/.cache/pip/wheels/14/f9/07/bb2308587bc2f57158f905a2325f6a89a2befa7437b2d7e137
# Successfully built sentence_transformers lit
# Installing collected packages: tokenizers, safetensors, mpmath, lit, cmake, wheel, tqdm, threadpoolctl, sympy, scipy, regex, nvidia-nccl-cu11, nvidia-cufft-cu11, nvidia-cuda-nvrtc-cu11, networkx, joblib, fsspec, filelock, scikit-learn, nvidia-nvtx-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nltk, huggingface-hub, transformers, nvidia-cusolver-cu11, nvidia-cudnn-cu11, triton, torch, torchvision, sentence_transformers
# Successfully installed cmake-3.27.5 filelock-3.12.4 fsspec-2023.9.1 huggingface-hub-0.17.2 joblib-1.3.2 lit-16.0.6 mpmath-1.3.0 networkx-3.1 nltk-3.8.1 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 regex-2023.8.8 safetensors-0.3.3 scikit-learn-1.3.1 scipy-1.11.2 sentence_transformers-2.2.2 sympy-1.12 threadpoolctl-3.2.0 tokenizers-0.13.3 torch-2.0.1 torchvision-0.15.2 tqdm-4.66.1 transformers-4.33.2 triton-2.0.0 wheel-0.41.2

# %% [markdown]
# ##Milvus Server
#
# We're going to create vector embedding from the movie's descriptions. So, we need a way to store, index, and search on those embeddngs. That's where Milvus comes in.
#
# We're using a relatively large dataset, at least for a personal computer. So, you may want to use a Zilliz Cloud instance to store these vectors.
#
# But, if yu want to stay with a local instance, you can download a docker compose configuration and run that.
#
# Here's how to get the compose file, and start the server.

# %%
! wget https://github.com/milvus-io/milvus/releases/download/v2.3.0/milvus-standalone-docker-compose.yml -O docker-compose.yml
! docker-compose up -d

# %% [markdown]
# If you want to use cloud, sign up for an account [here](https://cloud.zilliz.com).

# %% [markdown]
# ## Redis Server
#
# We are using Redis as a metadata storage service.

# %%
! docker run --name redis -d -p 6379:6379 redis
# Out:
# 1ce442c4e0ddb27fe1b19c23a173876833132c61a3985fbe84af4b54308dfd6f

# %% [markdown]
# Let's read in the movie metadata and see what it has to offer.

# %%
import pandas as pd

movies=pd.read_csv('dataset/movies_metadata.csv',low_memory=False)
movies.shape
# Out:
# (45466, 24)

# %% [markdown]
# We have more than 45k movies, with 24 coum,ns of metadata.
#
# Let's list the columns.

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# We don't need to store all these columns in Redis. Let's trim them down to the essentials.

# %%
trimmed_movies = movies[["id", "title", "overview", "release_date", "genres"]]
trimmed_movies.head(5)
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                             overview release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...   1995-12-15
# 2  A family wedding reignites the ancient feud be...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...   1995-12-22
# 4  Just when George Banks has recovered from his ...   1995-02-10
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]

# %% [markdown]
# Now, it's time to connect to Milvus and Redis so you can start uploading data.
#
# Start with Redis:

# %%
import redis                    
redis_server = redis.StrictRedis(host="localhost", port=6379)
redis_server.flushall()
# Out:
# True

# %% [markdown]
# Next, connect to Milvus.
#
# Here's the code for connecting to a cloud instance. Replace the URI and TOKEN with the correct values for your instance.
#
# You can find them in your Zilliz dashboard:
#
#
# ![image.png](cluster_info.png)

# %%
from pymilvus import *
import redis

milvus_uri="https://in03-75204f04fc4368d.api.gcp-us-west1.zillizcloud.com"
token="12ac8d384a8bae99c7fe00e34c112aa4095034cf45c7db6e5d8be9f974dbb737b116e983fbd350f6cf2e75406a74b7d030fc814e"
connections.connect("default",
                        uri=milvus_uri,
                        token=token)
print("Connected!")
# Out:
# Connected!

# %% [markdown]
# Now, let's import the movie metadat into redis. While we're doing this, we'll clean up the data by verifying that all the fields are present before insert the entry into Redis. Many of the movies are missing fields.

# %%
import json

movies_dict = trimmed_movies.to_dict('records')

for movie in movies_dict:
    if not movie["id"] or movie["overview"] != movie["overview"] or movie["release_date"] != movie["release_date"] or movie["genres"] != movie["genres"]:
        print("Dropping {}".format(movie))
        movies_dict.remove(movie)

    redis_server.set(str(movie['id']), json.dumps(movie))

print("Done importing movies into redis.")
# Out:
# Dropping {'id': '78802', 'title': 'Wings of Courage', 'overview': nan, 'release_date': '1996-09-18', 'genres': "[{'id': 10749, 'name': 'Romance'}, {'id': 12, 'name': 'Adventure'}]"}
# Dropping {'id': '161495', 'title': 'Roommates', 'overview': nan, 'release_date': '1995-03-01', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '287305', 'title': 'Peanuts – Die Bank zahlt alles', 'overview': nan, 'release_date': '1996-03-21', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '10801', 'title': 'The Superwife', 'overview': nan, 'release_date': '1996-03-06', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '278978', 'title': 'Und keiner weint mir nach', 'overview': nan, 'release_date': '1996-02-29', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '117730', 'title': 'Under The Domim Tree', 'overview': nan, 'release_date': '1994-01-01', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '365371', 'title': 'War Stories Our Mother Never Told Us', 'overview': 'Seven New Zealand women speak about their lives during World War II: some lost husbands, some got married, some went into service themselves. The director lets the women tell their stories simply, alternating between them talking and archival footage of the war years.', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '215107', 'title': 'Vermont Is for Lovers', 'overview': 'Vermont is for Lovers is an independently produced docudrama released in 1992, starring George Thrush and Marya Cohn and shot on location Tunbridge, Vermont. The film concerns a couple visiting Vermont in order to be married, and interviewing local residents on the subject of marriage.[Largely improvised and using non-professional actors, the film was shown at various film festivals including the Melbourne International Film Festival and the Hawaii International Film Festival. The movie was not terribly well received by the national press, with the New York Times calling it, "vaguely amiable". While the Washington Post review commented that the film was an "all-too-easy target for ridicule", it also mentioned one of the film\'s high points: "In one scene, a typically droll Vermont resident (playing himself) sums up his state\'s fabled coolness to strangers by suggesting that a sign be placed at the state line, reading "Welcome to Vermont. Now Leave.""', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '281085', 'title': 'A Boy Called Hate', 'overview': nan, 'release_date': '1996-05-22', 'genres': '[]'}
# Dropping {'id': '282919', 'title': 'Diebinnen', 'overview': nan, 'release_date': '1996-06-20', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '48144', 'title': 'The Day the Sun Turned Cold', 'overview': nan, 'release_date': '1994-01-01', 'genres': '[]'}
# Dropping {'id': '145925', 'title': 'Mille bolle blu', 'overview': nan, 'release_date': '1993-01-01', 'genres': '[]'}
# Dropping {'id': '253632', 'title': 'Baton Rouge', 'overview': nan, 'release_date': '1988-10-08', 'genres': "[{'id': 53, 'name': 'Thriller'}]"}
# Dropping {'id': '108365', 'title': 'The Proprietor', 'overview': nan, 'release_date': '1996-09-09', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '146341', 'title': 'Bird of Prey', 'overview': nan, 'release_date': '1995-09-12', 'genres': "[{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '43775', 'title': 'Guantanamera', 'overview': nan, 'release_date': '1995-01-01', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '60083', 'title': 'Salut cousin !', 'overview': nan, 'release_date': '1996-11-20', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '77314', 'title': 'The Cabinet of Dr. Ramirez', 'overview': nan, 'release_date': '1991-12-04', 'genres': '[]'}
# Dropping {'id': '134368', 'title': 'One Tough Cop', 'overview': nan, 'release_date': '1998-10-09', 'genres': '[]'}
# Dropping {'id': '94214', 'title': 'Jails, Hospitals & Hip-Hop', 'overview': 'Jails, Hospitals &amp; Hip-Hop is a cinematic tour de force that is unprecedented in film or hip-hop history. From the mind of Brooklyn actor, performance artist and hip-hop activist Danny Hoch, this film spins out the stories of ten lives shocked by global hip-hop, the prison system and life in general. Moving masterfully in and out of the characters while the camera cuts from film narrative to live performances, Danny blows your mind and makes you look at cultural power in a new way that is hysterically funny, tragically sad and uplifting all at once.', 'release_date': nan, 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '207731', 'title': "Boricua's Bond", 'overview': "Tommy, a talented Puerto Rican painter living in the South Bronx, befriends Allen, a white kid who's faced constant harassment since moving to the neighborhood with his single mother, Susan.", 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '109472', 'title': 'The Girl', 'overview': nan, 'release_date': '2001-06-06', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}, {'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '78657', 'title': 'Ouch', 'overview': nan, 'release_date': '2000-09-06', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '58886', 'title': "Everybody's Famous!", 'overview': nan, 'release_date': '2000-04-12', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '99885', 'title': 'Divine Intervention', 'overview': "Four friends fight an insane man's crusade to eliminate sinners from a small Western town.", 'release_date': nan, 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '29224', 'title': 'Jönssonligan & DynamitHarry', 'overview': nan, 'release_date': '1982-09-17', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '81346', 'title': 'To Begin Again', 'overview': nan, 'release_date': '1982-03-01', 'genres': '[]'}
# Dropping {'id': '61939', 'title': 'The Three Marias', 'overview': nan, 'release_date': '2002-01-01', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '65048', 'title': 'The Four Days of Naples', 'overview': nan, 'release_date': '1962-01-01', 'genres': '[]'}
# Dropping {'id': '53688', 'title': 'Stinsen brinner... filmen alltså', 'overview': nan, 'release_date': '1991-03-03', 'genres': '[]'}
# Dropping {'id': '175739', 'title': 'The Life of Aleksis Kivi', 'overview': nan, 'release_date': '2002-01-18', 'genres': '[]'}
# Dropping {'id': '100594', 'title': 'The Book of Fate', 'overview': nan, 'release_date': '2003-03-06', 'genres': "[{'id': 28, 'name': 'Action'}, {'id': 27, 'name': 'Horror'}, {'id': 878, 'name': 'Science Fiction'}]"}
# Dropping {'id': '32546', 'title': 'Lugares comunes', 'overview': nan, 'release_date': '2002-10-04', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '113178', 'title': 'A Wake in Providence', 'overview': nan, 'release_date': '1999-01-01', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '55396', 'title': 'Koirankynnen leikkaaja', 'overview': nan, 'release_date': '2004-02-12', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '68646', 'title': 'Superprodukcja', 'overview': nan, 'release_date': '2002-02-28', 'genres': '[]'}
# Dropping {'id': '52920', 'title': 'What Will You Do When You Catch Me?', 'overview': nan, 'release_date': '1978-12-08', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '155386', 'title': 'La Sierra', 'overview': nan, 'release_date': '2005-01-01', 'genres': '[]'}
# Dropping {'id': '22554', 'title': 'The Subtenant', 'overview': nan, 'release_date': '2008-09-12', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '47499', 'title': 'Small Cuts', 'overview': nan, 'release_date': '2003-02-12', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '55748', 'title': 'Ystäväni Henry', 'overview': nan, 'release_date': '2004-08-20', 'genres': '[]'}
# Dropping {'id': '55500', 'title': 'The Land of Happiness', 'overview': nan, 'release_date': '1993-04-30', 'genres': '[]'}
# Dropping {'id': '61070', 'title': 'Pekka ja Pätkä lumimiehen jäljillä', 'overview': nan, 'release_date': '1954-07-30', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '156908', 'title': 'Täynnä tarmoa', 'overview': nan, 'release_date': '2009-03-01', 'genres': '[]'}
# Dropping {'id': '210487', 'title': 'Człowiek z M-3', 'overview': nan, 'release_date': '1969-02-20', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '38869', 'title': 'Wyjście awaryjne', 'overview': nan, 'release_date': '1982-12-25', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '155426', 'title': 'Anioł w Krakowie', 'overview': nan, 'release_date': '2002-09-20', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '200796', 'title': 'Show', 'overview': nan, 'release_date': '2003-03-19', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 53, 'name': 'Thriller'}]"}
# Dropping {'id': '64968', 'title': 'Marius and Jeannette', 'overview': nan, 'release_date': '1997-01-01', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '156917', 'title': 'Pekka ja Pätkä neekereinä', 'overview': nan, 'release_date': '1960-03-11', 'genres': '[]'}
# Dropping {'id': '91205', 'title': 'Bling: A Planet Rock', 'overview': 'Bling is a documentary film which focuses on the complex relationship between “blood” diamonds, conflict, the influence of Hip-Hop music and culture, and community development. Produced by VH1 Rock Docs, Article 19 Films, and UNDP, the film features the participation of Hip-Hop artists from the US and Sierra Leone.  The objective of the film is not to shame people into boycotting diamonds. Instead, it is to raise a voice on behalf of the millions of diamond diggers and to help disadvantaged communities and entrepreneurs reach their full economic potential. Promoting conscious consumerism and using the power and influence of the hip-hop music, Bling tries to encourage buying "clean" diamonds.', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '66949', 'title': 'Molière', 'overview': nan, 'release_date': '1978-08-30', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}]"}
# Dropping {'id': '128856', 'title': 'Traffic Affairs', 'overview': nan, 'release_date': '2004-02-06', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '154430', 'title': 'Shadow of the Eagle', 'overview': nan, 'release_date': '2005-09-08', 'genres': '[]'}
# Dropping {'id': '41427', 'title': 'Questo piccolo grande amore', 'overview': nan, 'release_date': '2009-02-11', 'genres': '[]'}
# Dropping {'id': '140887', 'title': 'The Three Musketeers', 'overview': nan, 'release_date': '1933-04-07', 'genres': "[{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}]"}
# Dropping {'id': '18120', 'title': 'Brain Drain', 'overview': nan, 'release_date': '2009-01-01', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '63615', 'title': 'Un buen hombre', 'overview': nan, 'release_date': '2009-04-30', 'genres': '[]'}
# Dropping {'id': '63764', 'title': 'Devil in the Flesh', 'overview': nan, 'release_date': '1947-09-22', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '147683', 'title': 'The Prophet, the Gold, and the Transylvanians', 'overview': nan, 'release_date': '1978-02-12', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 37, 'name': 'Western'}]"}
# Dropping {'id': '148435', 'title': 'Pekka ja Pätkä Suezilla', 'overview': nan, 'release_date': '1958-12-08', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '144089', 'title': 'The Actress, the Dollars and the Transylvanians', 'overview': nan, 'release_date': '1978-12-22', 'genres': "[{'id': 28, 'name': 'Action'}, {'id': 37, 'name': 'Western'}]"}
# Dropping {'id': '147692', 'title': 'The Oil, the Baby and the Transylvanians', 'overview': nan, 'release_date': '1981-01-12', 'genres': "[{'id': 80, 'name': 'Crime'}, {'id': 37, 'name': 'Western'}]"}
# Dropping {'id': '62775', 'title': 'Havukka-Ahon Ajattelija', 'overview': nan, 'release_date': '2010-01-15', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '281287', 'title': 'Dead Ahead: The Exxon Valdez Disaster', 'overview': 'The real-life struggle to contain the environmental and financial damage caused to Alaska by the oil spill from the Exxon Valdez is dramatized.', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '120280', 'title': 'Pekka ja Pätkä puistotäteinä', 'overview': nan, 'release_date': '1955-03-04', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '117499', 'title': 'Asphalt Lambs', 'overview': nan, 'release_date': '1968-12-20', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '21245', 'title': 'Lovers & Leavers', 'overview': nan, 'release_date': '2002-02-01', 'genres': '[]'}
# Dropping {'id': '173865', 'title': 'Esa ja Vesa – auringonlaskun ratsastajat', 'overview': nan, 'release_date': '1994-11-10', 'genres': '[]'}
# Dropping {'id': '30695', 'title': 'Chance Pe Dance', 'overview': nan, 'release_date': '2010-01-15', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '46341', 'title': 'El próximo Oriente', 'overview': nan, 'release_date': '2006-08-14', 'genres': '[]'}
# Dropping {'id': '55403', 'title': 'Kulkuri ja joutsen', 'overview': nan, 'release_date': '1999-02-19', 'genres': '[]'}
# Dropping {'id': '74714', 'title': 'Diên Biên Phu', 'overview': nan, 'release_date': '1992-03-04', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10752, 'name': 'War'}]"}
# Dropping {'id': '90930', 'title': 'Strip-Tease', 'overview': nan, 'release_date': '1963-05-29', 'genres': '[]'}
# Dropping {'id': '370264', 'title': 'Provocateur', 'overview': nan, 'release_date': '1995-05-31', 'genres': "[{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '157178', 'title': 'Grający z talerza', 'overview': nan, 'release_date': '1995-11-07', 'genres': '[]'}
# Dropping {'id': '72421', 'title': 'Marcel Reich-Ranicki - Mein Leben', 'overview': nan, 'release_date': '2009-04-10', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '71732', 'title': 'The Right of the Weakest', 'overview': nan, 'release_date': '2006-07-19', 'genres': '[]'}
# Dropping {'id': '116751', 'title': 'The Little Thief', 'overview': nan, 'release_date': '1999-09-12', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '65898', 'title': 'The Suspended Vocation', 'overview': nan, 'release_date': '1978-07-27', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '102527', 'title': '44500 Max', 'overview': nan, 'release_date': '2009-09-01', 'genres': '[]'}
# Dropping {'id': '442417', 'title': 'Das Experiment 770 - Gebären auf Befehl', 'overview': '52min | Documentary | TV Movie 12 January 2005', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '53364', 'title': 'Der letzte schöne Herbsttag', 'overview': nan, 'release_date': '2010-11-11', 'genres': '[]'}
# Dropping {'id': '81414', 'title': 'Ingrid', 'overview': nan, 'release_date': '2010-04-30', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '54354', 'title': 'Eila', 'overview': nan, 'release_date': '2003-03-14', 'genres': '[]'}
# Dropping {'id': '367647', 'title': 'Connections', 'overview': 'Documentary  Follow James Burke through the history of science and technology. In this collection of 10 1-hour episodes, starting with "The Trigger Effect".', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '72375', 'title': 'Rien sur Robert', 'overview': nan, 'release_date': '1999-02-24', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '4880', 'title': 'Nichts als Gespenster', 'overview': nan, 'release_date': '2006-11-29', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '55408', 'title': 'Kymmenen riivinrautaa', 'overview': nan, 'release_date': '2002-08-30', 'genres': '[]'}
# Dropping {'id': '145154', 'title': 'Ballou', 'overview': nan, 'release_date': '2008-09-11', 'genres': '[]'}
# Dropping {'id': '3962', 'title': 'Bis zum Ellenbogen', 'overview': nan, 'release_date': '2007-11-01', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '74183', 'title': 'Vieraalla Maalla', 'overview': nan, 'release_date': '2003-12-19', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '55763', 'title': 'Vääpeli Körmy - Taisteluni', 'overview': nan, 'release_date': '1994-09-16', 'genres': '[]'}
# Dropping {'id': '55761', 'title': 'Vääpeli Körmy ja etelän hetelmät', 'overview': nan, 'release_date': '1992-10-09', 'genres': '[]'}
# Dropping {'id': '55754', 'title': 'Vääpeli Körmy ja vetenalaiset vehkeet', 'overview': nan, 'release_date': '1991-10-18', 'genres': '[]'}
# Dropping {'id': '148314', 'title': 'Pekko ja Unissakävelijä', 'overview': nan, 'release_date': '1997-09-26', 'genres': '[]'}
# Dropping {'id': '289010', 'title': 'Die Frau des Frisörs', 'overview': nan, 'release_date': '2008-10-27', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '55756', 'title': "Sergeant Körmy and the Marshall's Stick", 'overview': nan, 'release_date': '1990-11-02', 'genres': '[]'}
# Dropping {'id': '36663', 'title': 'Dreamkiller', 'overview': 'A team of doctors experiment with a new, highly controversial form of psycho therapy (named F.R.I.T.) designed to cure chronic FEAR and PHOBIA patients. Soon someone begins to kill the patients one by one and investigation uncovers that the patients died in the exact way that they feared they would. Who or what brought their fears to life?', 'release_date': nan, 'genres': "[{'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}]"}
# Dropping {'id': '177697', 'title': 'Hangtime', 'overview': nan, 'release_date': '2009-10-14', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '404479', 'title': 'Car Bpnus', 'overview': nan, 'release_date': '2001-01-01', 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '55166', 'title': 'Hurmaava joukkoitsemurha', 'overview': nan, 'release_date': '2000-03-03', 'genres': '[]'}
# Dropping {'id': '230680', 'title': 'Nachbarinnen', 'overview': nan, 'release_date': '2004-11-10', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '92465', 'title': 'Ponterosa', 'overview': nan, 'release_date': '2001-03-30', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '105287', 'title': 'Super 8 Stories', 'overview': nan, 'release_date': '2001-10-10', 'genres': "[{'id': 10402, 'name': 'Music'}, {'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '132227', 'title': 'La próxima estación', 'overview': nan, 'release_date': '2008-09-08', 'genres': '[]'}
# Dropping {'id': '72419', 'title': 'In jeder Sekunde', 'overview': nan, 'release_date': '2008-12-11', 'genres': '[]'}
# Dropping {'id': '434973', 'title': 'Sokkotanssi', 'overview': nan, 'release_date': '1999-03-12', 'genres': '[]'}
# Dropping {'id': '86126', 'title': 'A Cab for Three', 'overview': nan, 'release_date': '2001-08-02', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}]"}
# Dropping {'id': '344741', 'title': 'Pajęczarki', 'overview': nan, 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '62614', 'title': 'Hella W', 'overview': nan, 'release_date': '2011-01-01', 'genres': '[]'}
# Dropping {'id': '61121', 'title': 'Colorado Avenue', 'overview': nan, 'release_date': '2007-09-07', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '74878', 'title': 'Cloportes', 'overview': nan, 'release_date': '1965-10-01', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}]"}
# Dropping {'id': '257608', 'title': 'Khanei ruye ab', 'overview': "Director Bahman Farmanara's second film following a 20-year exile from his native Iran depicts the spiritual crisis of a middle-aged man. In the film's dreamlike opening scene, Dr. Reza Sepidbakht (Reza Kianian), a well-off Tehran gynecologist, thinks he runs over an angel while driving home at night with a call girl. The next morning at the hospital where he works, he is shown a comatose boy who is famous for having memorized the entire Koran. These two events cause him to rethink his cynical outlook on life and his relationships with his elderly father, wayward son, and the women he has mistreated since becoming estranged from his wife. When the boy awakens from his coma, Dr. Sepidbakht begins to look to him for answers.", 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '162374', 'title': 'Top Floor Left Wing', 'overview': nan, 'release_date': '2010-11-15', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '145594', 'title': 'Descongelate!', 'overview': nan, 'release_date': '2003-09-12', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '31337', 'title': 'Contact High', 'overview': nan, 'release_date': '2009-03-19', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '404471', 'title': 'Pölynimurikauppiaat', 'overview': nan, 'release_date': nan, 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '247500', 'title': 'Le 7ème juré', 'overview': nan, 'release_date': '2008-05-16', 'genres': "[{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '85883', 'title': 'The Woman Who Drinks', 'overview': nan, 'release_date': '2001-03-09', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '399229', 'title': 'Kovat Miehet', 'overview': nan, 'release_date': '1999-01-01', 'genres': '[]'}
# Dropping {'id': '86727', 'title': 'Le Crabe-Tambour', 'overview': nan, 'release_date': '1977-11-09', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10752, 'name': 'War'}]"}
# Dropping {'id': '61361', 'title': "L'outremangeur", 'overview': nan, 'release_date': '2002-09-10', 'genres': "[{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '362151', 'title': 'Nuoruuteni savotat', 'overview': nan, 'release_date': '1988-11-18', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '78999', 'title': 'Virtual JFK: Vietnam If Kennedy Had Lived', 'overview': nan, 'release_date': '2008-09-17', 'genres': '[]'}
# Dropping {'id': '116019', 'title': 'Taistelu Näsilinnasta 1918', 'overview': nan, 'release_date': '2012-03-23', 'genres': "[{'id': 10752, 'name': 'War'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '458428', 'title': 'Operación Cannabis', 'overview': nan, 'release_date': '2009-11-01', 'genres': "[{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '118013', 'title': 'Endeavour', 'overview': "Shaun Evans (The Take) steps into John Thaw's shoes as the younger version of Colin Dexter's iconic creation, Inspector Morse, shedding new light on the origins of the detective famed for his love of crosswords, classical music, real ale, and classic cars.", 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '110491', 'title': 'The Manzanar Fishing Club', 'overview': nan, 'release_date': '2012-03-30', 'genres': "[{'id': 99, 'name': 'Documentary'}, {'id': 12, 'name': 'Adventure'}, {'id': 36, 'name': 'History'}]"}
# Dropping {'id': '79034', 'title': 'La Californie', 'overview': nan, 'release_date': '2006-10-26', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '35623', 'title': 'For My Father', 'overview': nan, 'release_date': '2008-06-13', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '112973', 'title': "A Pig's Tale", 'overview': nan, 'release_date': '1996-06-07', 'genres': "[{'id': 12, 'name': 'Adventure'}, {'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '76703', 'title': 'Quadrille', 'overview': nan, 'release_date': '1938-01-29', 'genres': "[{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '262988', 'title': 'The Men Who Made the Movies: Samuel Fuller', 'overview': nan, 'release_date': '2002-07-02', 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '82663', 'title': nan, 'overview': "British soldiers force a recently captured IRA terrorist to cooperate with them and then assign him to go undercover with a gang of terrorists and prevent them from killing the U.S. President. But the spy isn't in long before he realizes that the first plot is but a ruse for a more sinister scheme that could result in trouble between China and Great Britain.", 'release_date': nan, 'genres': "[{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '156180', 'title': 'Amor?', 'overview': nan, 'release_date': '2011-06-07', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '62012', 'title': 'Le Poulpe', 'overview': nan, 'release_date': '1998-10-07', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '328712', 'title': 'Tarda estate', 'overview': nan, 'release_date': '2010-09-04', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '26152', 'title': 'Erreur de la banque en votre faveur', 'overview': nan, 'release_date': '2009-04-08', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '128637', 'title': 'American Roulette', 'overview': nan, 'release_date': '1988-01-01', 'genres': "[{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '64362', 'title': 'Oui, mais...', 'overview': nan, 'release_date': '2001-04-18', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '397339', 'title': 'The Awful Truth', 'overview': 'Black and White', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '154792', 'title': 'Electile Dysfunction: Inside the Business of American Campaigns', 'overview': 'Filmmakers Joe Barber and Mary Patel examine the dysfunctional world of American politics through the prism of the 2006 United States Senate race between Democrat Bob Casey Jr. and Republican Rick Santorum. Gullible media, corporate influence and hyper-managed candidate personas are among the myriad subjects covered in this incisive documentary, which includes interviews with Barack Obama, Al Gore, Ed Rendell and many others.', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '177522', 'title': 'Lipton Cockton in the Shadows of Sodoma', 'overview': nan, 'release_date': '1995-04-21', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 9648, 'name': 'Mystery'}, {'id': 878, 'name': 'Science Fiction'}]"}
# Dropping {'id': '72678', 'title': 'Henry', 'overview': nan, 'release_date': '2010-03-31', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '139909', 'title': 'Aurinkotuuli', 'overview': nan, 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '128644', 'title': 'Marked for Murder', 'overview': nan, 'release_date': '1993-01-17', 'genres': '[]'}
# Dropping {'id': '367678', 'title': 'Enola Gay and the Atomic Bombing of Japan', 'overview': 'American Documentary', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '76686', 'title': 'The Green Wave', 'overview': nan, 'release_date': '2012-08-10', 'genres': '[]'}
# Dropping {'id': '334317', 'title': 'Désiré', 'overview': nan, 'release_date': '1993-04-05', 'genres': "[{'id': 878, 'name': 'Science Fiction'}]"}
# Dropping {'id': '81225', 'title': 'Abendland', 'overview': nan, 'release_date': '2011-03-31', 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '134806', 'title': 'Riders of the Purple Sage', 'overview': nan, 'release_date': '1996-01-21', 'genres': "[{'id': 10770, 'name': 'TV Movie'}, {'id': 18, 'name': 'Drama'}, {'id': 37, 'name': 'Western'}, {'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '116059', 'title': 'Laffghanistan: Comedy Down Range', 'overview': "Stand up comedian Graham Elwood's journey physically, and emotionally, as he travels through Afghanistan's war zones to entertain the embattled U.S. troops.", 'release_date': nan, 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '62130', 'title': 'El Big Bang de Tunguska', 'overview': nan, 'release_date': '2008-06-01', 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '131822', 'title': 'Kuningas Litmanen', 'overview': nan, 'release_date': '2012-09-28', 'genres': '[]'}
# Dropping {'id': '142989', 'title': 'A Get2Gether', 'overview': nan, 'release_date': '2005-09-28', 'genres': '[]'}
# Dropping {'id': '54356', 'title': 'Emmauksen tiellä', 'overview': nan, 'release_date': '2001-09-26', 'genres': '[]'}
# Dropping {'id': '149469', 'title': 'Carne de gallina', 'overview': nan, 'release_date': '2001-10-26', 'genres': '[]'}
# Dropping {'id': '65646', 'title': 'The Eternal Return', 'overview': nan, 'release_date': '1943-12-13', 'genres': "[{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '55524', 'title': 'Prinsessa Ruusunen', 'overview': nan, 'release_date': '1949-04-08', 'genres': '[]'}
# Dropping {'id': '82662', 'title': "L'industriale", 'overview': nan, 'release_date': '2011-01-13', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '38875', 'title': 'Senność', 'overview': nan, 'release_date': '2008-10-17', 'genres': "[{'id': 53, 'name': 'Thriller'}]"}
# Dropping {'id': '388046', 'title': 'Donos de Portugal', 'overview': nan, 'release_date': '2012-04-25', 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '67272', 'title': 'Känd från TV', 'overview': nan, 'release_date': '2001-09-21', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '83342', 'title': 'Blutzbrüdaz', 'overview': nan, 'release_date': '2011-12-28', 'genres': "[{'id': 10402, 'name': 'Music'}, {'id': 18, 'name': 'Drama'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '93649', 'title': 'Reflection', 'overview': "Nadine (Lisa Sookhiram) is sucked into an otherworld through the mirror -- but nobody knows it; they still see her, but it's her reflection. Yet everyone's puzzled by the new Nadine's aggressively sexual and dangerous behavior. Can her boyfriend, Eric (James Kautz, former World Kickboxing Champion), stop her from going down this path of destruction? Will the real Nadine ever come back?", 'release_date': nan, 'genres': "[{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 878, 'name': 'Science Fiction'}]"}
# Dropping {'id': '60824', 'title': 'Lune Froide', 'overview': nan, 'release_date': '1991-05-22', 'genres': '[]'}
# Dropping {'id': '173914', 'title': 'Sēņotāji', 'overview': nan, 'release_date': '2013-03-07', 'genres': '[]'}
# Dropping {'id': '65958', 'title': 'The Supper', 'overview': nan, 'release_date': '1992-12-23', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}]"}
# Dropping {'id': '217038', 'title': 'Dolly and Her Lover', 'overview': nan, 'release_date': '1990-02-01', 'genres': "[{'id': 80, 'name': 'Crime'}, {'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '455027', 'title': 'Dance of Outlaws', 'overview': 'A film about a woman who doesn’t exist. Moroccan Hind was raped and consequently denied an official identity – she has no other choice but to work as a prostitute and traditional wedding dancer, but despite the odds of her situation, refuses to give up her dream of dignity, motherhood and love.  This is a story of modern day outlaws, children of prostitutes, abandoned child brides and those who have had to escape to the fringes of patriarchal Moroccan society. Through the eyes of one young woman we see a life of constant struggle, but also a life free of the society’s norms and boundaries. The woman in the centre of the film, Hind, is both vulnerable and courageous as she tries to regain her life, her children and her mere right to live as an equal human being in the 21st century.', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '77776', 'title': 'La Dilettante', 'overview': nan, 'release_date': '1999-07-07', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '161073', 'title': 'Mariage à Mendoza', 'overview': nan, 'release_date': '2013-01-23', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '19623', 'title': 'Drona', 'overview': nan, 'release_date': '2008-10-02', 'genres': "[{'id': 28, 'name': 'Action'}, {'id': 10769, 'name': 'Foreign'}, {'id': 53, 'name': 'Thriller'}]"}
# Dropping {'id': '153196', 'title': 'Rosas Höllenfahrt', 'overview': nan, 'release_date': '2009-10-31', 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '82627', 'title': "Man On a Mission: Richard Garriott's Road to the Stars", 'overview': nan, 'release_date': '2010-03-14', 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '250503', 'title': 'Bad Chicken', 'overview': "All Norah ever wanted to be was a reality TV star. But her dream-come-true quickly turns into a nightmare when she allows a motley television crew of chickens, led by a sociopath, 'Charlie Chicken', to invade her home, manipulate her emotions, and drag her and her soon-to-be-ex-boyfriend into the desert on what is supposed to be a glamorous reality TV shoot. Deep in the surreal landscapes of the Joshua Tree desert, it becomes a battle of species. The hilarious antics of the oddball chicken crew, the blind faith of a reality TV star wannabe, and the cruel perversions of one really 'bad chicken', all spiral downward into an extremely unique Spaghetti Western.", 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '52045', 'title': 'Libre échange', 'overview': nan, 'release_date': '2010-12-22', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '173433', 'title': 'Holes in My Shoes', 'overview': '94-year-old New Yorker, Jack Beers, has broken the age barrier full force. He can do what most young men can, and his diverse lifetime achievements would take many to accomplish. The film begins with Mayor Bloomberg acknowledging Jack, we see Jack\'s name on the marquee of Radio City Music Hall, and at 94 he rips a telephone book into 4 pieces with his hands. Jack was raised in poverty in Manhattan, was a strongman, built Radio City Music Hall, at The Manhattan Project he invented something that shortened WW2, erected the Empire State Building spire, was a professional dog trainer, was a film actor in 200+ films, beat terminal illnesses, and today rides 5 miles on a stationary bike. He\'s "goin\' for 100!"', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '430985', 'title': 'The Diamond Fleece', 'overview': nan, 'release_date': '1992-09-17', 'genres': '[]'}
# Dropping {'id': '85469', 'title': 'Einer wie Bruno', 'overview': nan, 'release_date': '2012-04-12', 'genres': '[]'}
# Dropping {'id': '388182', 'title': 'هیچ کجا هیچ کس', 'overview': nan, 'release_date': '2013-08-07', 'genres': "[{'id': 9648, 'name': 'Mystery'}, {'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '130233', 'title': 'Fly Away', 'overview': nan, 'release_date': '2012-07-12', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '267219', 'title': 'Serrallonga', 'overview': nan, 'release_date': '2008-01-01', 'genres': '[]'}
# Dropping {'id': '110992', 'title': "Summer of '62", 'overview': nan, 'release_date': '2007-08-08', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '81600', 'title': 'Stille Nacht', 'overview': nan, 'release_date': '2004-09-16', 'genres': "[{'id': 53, 'name': 'Thriller'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '91380', 'title': "Les aventures d'Arsène Lupin", 'overview': nan, 'release_date': '1957-03-22', 'genres': "[{'id': 9648, 'name': 'Mystery'}, {'id': 80, 'name': 'Crime'}]"}
# Dropping {'id': '101352', 'title': "L'Antisémite", 'overview': nan, 'release_date': '2012-03-21', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '297560', 'title': 'Το Ξύλο Βγήκε Από Τον Παράδεισο', 'overview': nan, 'release_date': '1959-11-16', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '331958', 'title': 'Λατέρνα, Φτώχεια και Γαρύφαλλο', 'overview': nan, 'release_date': '1954-03-31', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '52150', 'title': 'Zincirbozan', 'overview': nan, 'release_date': '2007-04-13', 'genres': '[]'}
# Dropping {'id': '216369', 'title': 'Tentação', 'overview': nan, 'release_date': '1997-12-26', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '172890', 'title': 'Metastases', 'overview': nan, 'release_date': '2012-03-01', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '52147', 'title': 'Ulak', 'overview': nan, 'release_date': '2008-02-25', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 9648, 'name': 'Mystery'}]"}
# Dropping {'id': '246320', 'title': 'The Three Brothers: The Return', 'overview': nan, 'release_date': '2014-02-12', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '158517', 'title': 'Lain ulkopuolella', 'overview': "On her way home from an evening shift at a men's clothing store, Saara Nevanen is raped by a man whom she recognizes as her regular but eccentric customer, Antti Kaironen. The doctor and policemen question Saara in an insensitive manner,and she breaks down with guilt. When the court releases the perpetrator inlack of evidence, Saara's aggressive brother Jari talks her mild-mannered husband Sakari into a self-made revenge plot. Armed with two rifles, Jari and Sakari take matters into their own hands.", 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '32547', 'title': 'Social Genocide', 'overview': nan, 'release_date': '2004-03-18', 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '418029', 'title': 'Ultraman', 'overview': nan, 'release_date': '1967-07-21', 'genres': "[{'id': 28, 'name': 'Action'}, {'id': 878, 'name': 'Science Fiction'}]"}
# Dropping {'id': '142984', 'title': 'Scott Joplin', 'overview': nan, 'release_date': '1977-12-30', 'genres': '[]'}
# Dropping {'id': '204765', 'title': 'Prêt à tout', 'overview': nan, 'release_date': '2014-01-21', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '68827', 'title': 'She Does Not Drink Smoke or Flirts but She Talks', 'overview': nan, 'release_date': '1970-04-17', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '116894', 'title': 'Blind Terror', 'overview': nan, 'release_date': '2001-04-23', 'genres': "[{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}, {'id': 9648, 'name': 'Mystery'}]"}
# Dropping {'id': '55825', 'title': 'Spider', 'overview': nan, 'release_date': '2007-06-17', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '394403', 'title': 'Schwestern', 'overview': nan, 'release_date': '2014-03-21', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '202183', 'title': 'Ein Schnitzel für drei', 'overview': nan, 'release_date': '2010-06-01', 'genres': '[]'}
# Dropping {'id': '272543', 'title': 'Die Fischerin', 'overview': nan, 'release_date': '2014-05-23', 'genres': "[{'id': 10770, 'name': 'TV Movie'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '173151', 'title': 'El chocolate del loro', 'overview': nan, 'release_date': '2004-10-29', 'genres': '[]'}
# Dropping {'id': '206574', 'title': 'Unrated II: Scary as Hell', 'overview': nan, 'release_date': '2011-02-26', 'genres': "[{'id': 27, 'name': 'Horror'}]"}
# Dropping {'id': '60106', 'title': 'Loser Takes All!', 'overview': nan, 'release_date': '2004-06-23', 'genres': "[{'id': 9648, 'name': 'Mystery'}, {'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '164419', 'title': 'Maata meren alla', 'overview': nan, 'release_date': '2009-01-23', 'genres': '[]'}
# Dropping {'id': '44155', 'title': 'The Italian', 'overview': nan, 'release_date': '2010-07-07', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '64934', 'title': 'Le Nouveau Jean-Claude', 'overview': nan, 'release_date': '2002-06-26', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '74950', 'title': 'Breakout', 'overview': nan, 'release_date': '2007-01-18', 'genres': "[{'id': 10402, 'name': 'Music'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '2692', 'title': 'The Red Elvis', 'overview': nan, 'release_date': '2007-02-13', 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '76846', 'title': 'A Guy and a Gal', 'overview': nan, 'release_date': '1975-06-25', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '173300', 'title': 'Getting Back to Abnormal', 'overview': "What happens when America's most joyous, dysfunctional city rebuilds itself after a disaster? New Orleans is the setting for Getting Back to Abnormal, a film that serves up a provocative mix of race, corruption and politics to tell the story of the re-election campaign of Stacy Head, a white woman in a city council seat traditionally held by a black representative. Supported by her irrepressible African-American aide Barbara Lacen-Keller, Head polarizes the city as her candidacy threatens to diminish the power and influence of its black citizens. Featuring a cast of characters as colorful as the city itself, the film presents a New Orleans that outsiders rarely see.", 'release_date': nan, 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '329227', 'title': 'Mi Amigo Hugo', 'overview': nan, 'release_date': '2014-03-05', 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '343693', 'title': 'Aladin', 'overview': nan, 'release_date': '2008-08-12', 'genres': "[{'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}]"}
# Dropping {'id': '287831', 'title': 'External Affairs', 'overview': 'Harry Raymond, a foreign ambassador in Moscow, is at the pinnacle of a distinguished career when he is implicated in the savage murder of a young Russian artist. Stars Henry Czerny, Victor Garber.', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '182799', 'title': 'Cement', 'overview': nan, 'release_date': '2000-04-03', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}]"}
# Dropping {'id': '230295', 'title': 'Hur som helst är han jävligt död', 'overview': nan, 'release_date': '2000-08-31', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '42416', 'title': 'Arrapaho', 'overview': nan, 'release_date': '1984-01-01', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '273510', 'title': 'Madame Bovary', 'overview': nan, 'release_date': '2000-06-02', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '12076', 'title': 'Elsk meg i morgen', 'overview': nan, 'release_date': '2005-09-23', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '127375', 'title': "America's Most Haunted Inns", 'overview': 'Welcome to the modest small town of Bucks County, Pennsylvania. Enjoy your stay at Bucksville house and have your room tidied up in the morning by colonial maids who turn and vanish. At the Wedgewood Inn, explore a tunnel of the Underground Railroad where slaves passed through to freedom and the spirits of some still linger. Examine the mystery of the figure on horseback, spotted in the woods outside the Arianna Miles, as this fascinating documentary reveals some of the most amazing images of spirits ever recorded!', 'release_date': nan, 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '204768', 'title': 'Les invincibles', 'overview': nan, 'release_date': '2013-09-18', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '117678', 'title': "Dans la peau d'une grande", 'overview': nan, 'release_date': '2011-10-27', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '198130', 'title': 'Pop Redemption', 'overview': nan, 'release_date': '2013-06-05', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '204965', 'title': 'Drei Stunden', 'overview': nan, 'release_date': '2013-07-24', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '151730', 'title': 'Eat', 'overview': nan, 'release_date': '1963-12-31', 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '124207', 'title': 'The Devil and Holy Water', 'overview': nan, 'release_date': '1983-09-01', 'genres': '[]'}
# Dropping {'id': '42438', 'title': 'Ricky e Barabba', 'overview': nan, 'release_date': '1992-12-19', 'genres': '[]'}
# Dropping {'id': '56971', 'title': 'The New Monsters Today', 'overview': nan, 'release_date': '2009-03-27', 'genres': '[]'}
# Dropping {'id': '42441', 'title': 'Tifosi', 'overview': nan, 'release_date': '1999-10-01', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '121510', 'title': "Il tifoso l'arbitro e il calciatore", 'overview': nan, 'release_date': '1982-08-01', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '48935', 'title': 'Viuuulentemente mia', 'overview': nan, 'release_date': '1982-03-15', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '205349', 'title': 'I due Pompieri', 'overview': nan, 'release_date': '1968-07-02', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '285532', 'title': "Bolidi sull'asfalto a tutta birra!", 'overview': nan, 'release_date': '1970-08-08', 'genres': "[{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}, {'id': 16, 'name': 'Animation'}]"}
# Dropping {'id': '255906', 'title': 'Il figlio dello sceicco', 'overview': nan, 'release_date': '1977-02-16', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 28, 'name': 'Action'}]"}
# Dropping {'id': '52238', 'title': 'Squadra antigangsters', 'overview': nan, 'release_date': '1979-10-10', 'genres': '[]'}
# Dropping {'id': '127760', 'title': "Uno contro l'altro praticamente amici", 'overview': nan, 'release_date': '1980-12-01', 'genres': '[]'}
# Dropping {'id': '212503', 'title': 'King Ordinary', 'overview': nan, 'release_date': '2013-09-04', 'genres': "[{'id': 10770, 'name': 'TV Movie'}, {'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '307113', 'title': 'Presidentintekijät', 'overview': nan, 'release_date': '2014-03-14', 'genres': '[]'}
# Dropping {'id': '129062', 'title': "Bullets Don't Argue", 'overview': nan, 'release_date': '1964-08-21', 'genres': "[{'id': 37, 'name': 'Western'}]"}
# Dropping {'id': '302118', 'title': 'Quatsch und die Nasenbärbande', 'overview': nan, 'release_date': '2014-10-13', 'genres': "[{'id': 10751, 'name': 'Family'}]"}
# Dropping {'id': '55553', 'title': 'Rakkaudella, Maire', 'overview': nan, 'release_date': '1999-09-17', 'genres': '[]'}
# Dropping {'id': '197335', 'title': 'Se tutto va bene siamo rovinati', 'overview': nan, 'release_date': '1983-12-29', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '48805', 'title': "L'allenatore nel pallone 2", 'overview': nan, 'release_date': '2008-01-11', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '128946', 'title': 'Lille Fridolf Och Jag', 'overview': nan, 'release_date': '1956-10-29', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '59040', 'title': 'I due carabinieri', 'overview': nan, 'release_date': '1984-01-01', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '56825', 'title': 'Compagni di scuola', 'overview': nan, 'release_date': '1988-12-12', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '56551', 'title': "Maledetto il giorno che t'ho incontrato", 'overview': nan, 'release_date': '1992-01-31', 'genres': '[]'}
# Dropping {'id': '58081', 'title': 'Iris Blond', 'overview': nan, 'release_date': '1996-01-01', 'genres': '[]'}
# ...
# Dropping {'id': '74171', 'title': 'Sahte Kabadayı', 'overview': nan, 'release_date': '1976-09-01', 'genres': '[]'}
# Dropping {'id': '123601', 'title': 'Sosyete Şaban', 'overview': nan, 'release_date': '1985-01-01', 'genres': '[]'}
# Dropping {'id': '123611', 'title': 'Tokatçı', 'overview': nan, 'release_date': '1983-01-01', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '409926', 'title': 'Cosmos', 'overview': 'Astronomer Dr. Carl Sagan is host and narrator of this 13-hour series that originally aired on Public Broadcasting Stations in the United States. Dr. Sagan describes the universe in a way that appeals to a mass audience, by using Earth as a reference point, by speaking in terms intelligible to non-scientific people, by relating the exploration of space to that of the Earth by pioneers of old, and by citing such Earth legends as the Library of Alexandria as metaphors for space-related future events. Among Dr. Sagan\'s favorite topics are the origins of life, the search for life on Mars, the infernal composition of the atmosphere of Venus and a warning about a similar effect taking place on Earth due to global pollution and the "greenhouse effect", the lives of stars, interstellar travel and the effects of attaining the speed of light, the danger of mankind technologically self-destructing, and the search, using radio technology, for intelligent life in deep space.', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '453596', 'title': 'Kolonya Cumhuriyeti', 'overview': nan, 'release_date': '2017-04-20', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '142802', 'title': 'Гонгофер', 'overview': nan, 'release_date': '1992-01-01', 'genres': "[{'id': 12, 'name': 'Adventure'}, {'id': 27, 'name': 'Horror'}, {'id': 9648, 'name': 'Mystery'}]"}
# Dropping {'id': '439998', 'title': "Omicidio all'italiana", 'overview': nan, 'release_date': '2017-03-02', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '143883', 'title': 'Den radio', 'overview': nan, 'release_date': '2001-03-24', 'genres': "[{'id': 10770, 'name': 'TV Movie'}]"}
# Dropping {'id': '354133', 'title': 'Zombeak', 'overview': nan, 'release_date': '2006-06-06', 'genres': "[{'id': 27, 'name': 'Horror'}]"}
# Dropping {'id': '191486', 'title': 'Поезд вне расписания', 'overview': nan, 'release_date': '1986-05-12', 'genres': '[]'}
# Dropping {'id': '127803', 'title': '3 Times a Charm', 'overview': nan, 'release_date': '2011-01-01', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '271495', 'title': 'Dialogues', 'overview': nan, 'release_date': '2014-04-24', 'genres': '[]'}
# Dropping {'id': '244575', 'title': 'Кентервильское привидение', 'overview': nan, 'release_date': '1970-12-19', 'genres': "[{'id': 16, 'name': 'Animation'}]"}
# Dropping {'id': '246438', 'title': 'Семь кабинок', 'overview': nan, 'release_date': '2007-02-07', 'genres': '[]'}
# Dropping {'id': '400796', 'title': 'Irwin & Fran 2013', 'overview': "Professor Irwin Corey is now 101 years old and he is a well known comedian, entertainer and political satirist. Fran is 95 and his wife of 71 years. Dick Gregory shares Irwin's contribution and family friend Susan Sarandon narrates.", 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '36264', 'title': 'The Deserters', 'overview': nan, 'release_date': '1986-09-22', 'genres': "[{'id': 10752, 'name': 'War'}, {'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '270908', 'title': 'Совершенно серьезно', 'overview': nan, 'release_date': '1961-10-17', 'genres': '[]'}
# Dropping {'id': '14210', 'title': 'Nightmare City 2035', 'overview': nan, 'release_date': '2007-01-01', 'genres': "[{'id': 878, 'name': 'Science Fiction'}]"}
# Dropping {'id': '441826', 'title': 'Shivering Trunks', 'overview': "Natalia Brożyńska's animation debut, about dramatic love, acceptance and happy endings.", 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '376934', 'title': 'Restart', 'overview': nan, 'release_date': '2005-01-10', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '213321', 'title': 'Investigation Held by Kolobki', 'overview': nan, 'release_date': '1986-01-01', 'genres': "[{'id': 16, 'name': 'Animation'}]"}
# Dropping {'id': '380438', 'title': "Lettre d'une inconnue", 'overview': nan, 'release_date': '2001-01-01', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '41493', 'title': 'Karlsson on the Roof', 'overview': nan, 'release_date': '2002-09-27', 'genres': "[{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}]"}
# Dropping {'id': '452922', 'title': 'Supermassive Black Holes', 'overview': nan, 'release_date': nan, 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '93461', 'title': 'Sexy boys', 'overview': nan, 'release_date': '2001-12-26', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '340155', 'title': 'Игра на выбывание', 'overview': "Inhabitants of an elite Moscow house get involved in a game of a terrorist threatening to kill them one by one if they don't pay them a large amount of money.", 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '63838', 'title': 'Mechenosets', 'overview': nan, 'release_date': '2006-10-12', 'genres': "[{'id': 28, 'name': 'Action'}, {'id': 10749, 'name': 'Romance'}, {'id': 53, 'name': 'Thriller'}, {'id': 878, 'name': 'Science Fiction'}]"}
# Dropping {'id': '197057', 'title': 'А поутру они проснулись', 'overview': nan, 'release_date': '2003-12-04', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '336484', 'title': 'Каменная башка', 'overview': nan, 'release_date': '2008-09-18', 'genres': "[{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '159810', 'title': 'Caravaggio', 'overview': nan, 'release_date': '2007-07-03', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}]"}
# Dropping {'id': '51275', 'title': 'The Priest', 'overview': nan, 'release_date': '2009-04-04', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}, {'id': 10752, 'name': 'War'}]"}
# Dropping {'id': '420481', 'title': 'Путь к себе', 'overview': nan, 'release_date': '2010-04-10', 'genres': "[{'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '26792', 'title': 'The Storm Gate', 'overview': nan, 'release_date': '2006-02-12', 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}]"}
# Dropping {'id': '48209', 'title': 'Hamlet, Prince of Denmark', 'overview': nan, 'release_date': '1961-01-01', 'genres': "[{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '456956', 'title': 'Neither Wolf Nor Dog', 'overview': 'A white author is sucked into a road trip through the heart on Native American Country by a Lakota elder and his best friend forcing the author into a deep understanding of contemporary native life.', 'release_date': nan, 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '57382', 'title': "Halal Police d'Etat", 'overview': nan, 'release_date': '2011-02-16', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '110131', 'title': 'The Man of Gold', 'overview': nan, 'release_date': '1962-12-13', 'genres': "[{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}]"}
# Dropping {'id': '41689', 'title': 'Abigél', 'overview': nan, 'release_date': '1978-01-01', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '458808', 'title': 'Nice Places to Die', 'overview': nan, 'release_date': '2015-06-04', 'genres': "[{'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '400552', 'title': 'Happy Burnout', 'overview': nan, 'release_date': '2017-04-11', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '419601', 'title': 'Поэма о крыльях', 'overview': nan, 'release_date': '1979-07-06', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '14644', 'title': 'Boudu', 'overview': nan, 'release_date': '2005-03-09', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '82495', 'title': 'Gamer', 'overview': nan, 'release_date': '2001-03-21', 'genres': "[{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 10769, 'name': 'Foreign'}]"}
# Dropping {'id': '64827', 'title': "L'educazione sentimentale di Eugenie", 'overview': nan, 'release_date': '2005-01-01', 'genres': '[]'}
# Dropping {'id': '103301', 'title': 'Babnik', 'overview': nan, 'release_date': '1990-02-01', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '301876', 'title': '30 Years to Life', 'overview': nan, 'release_date': '1998-01-01', 'genres': "[{'id': 878, 'name': 'Science Fiction'}, {'id': 53, 'name': 'Thriller'}]"}
# Dropping {'id': '73545', 'title': 'Ехали в трамвае Ильф и Петров', 'overview': nan, 'release_date': '1972-08-19', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '448879', 'title': 'Приключения Домовёнка', 'overview': nan, 'release_date': '1986-03-25', 'genres': "[{'id': 16, 'name': 'Animation'}]"}
# Dropping {'id': '457307', 'title': 'Don\'t call him "Dimon"', 'overview': nan, 'release_date': '2017-03-02', 'genres': "[{'id': 9648, 'name': 'Mystery'}, {'id': 99, 'name': 'Documentary'}]"}
# Dropping {'id': '396987', 'title': 'Медведь', 'overview': nan, 'release_date': '1938-06-11', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '153561', 'title': 'La buena nueva', 'overview': nan, 'release_date': '2008-11-14', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '366860', 'title': 'El Violetero', 'overview': nan, 'release_date': '1960-11-24', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '202865', 'title': 'The Gerber Syndrome: Il Contagio', 'overview': nan, 'release_date': '2011-06-21', 'genres': "[{'id': 27, 'name': 'Horror'}]"}
# Dropping {'id': '9765', 'title': 'Der große Bagarozy', 'overview': nan, 'release_date': '1999-10-06', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '213683', 'title': 'Перекресток', 'overview': nan, 'release_date': '1998-12-30', 'genres': "[{'id': 10749, 'name': 'Romance'}]"}
# Dropping {'id': '425916', 'title': 'Salad Fingers', 'overview': 'The adventures of Salad Fingers, an unspecified mutated creature driven to madness by his loneliness.', 'release_date': nan, 'genres': "[{'id': 16, 'name': 'Animation'}, {'id': 27, 'name': 'Horror'}, {'id': 878, 'name': 'Science Fiction'}]"}
# Dropping {'id': '142320', 'title': "Viva l'Italia", 'overview': nan, 'release_date': '2012-10-25', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '430058', 'title': 'Votez Bougon', 'overview': nan, 'release_date': '2016-12-16', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '54309', 'title': 'Notte prima degli esami - Oggi', 'overview': nan, 'release_date': '2007-02-14', 'genres': '[]'}
# Dropping {'id': '445840', 'title': 'Selfie', 'overview': nan, 'release_date': '2017-06-23', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '64043', 'title': 'I due orfanelli', 'overview': nan, 'release_date': '1947-01-01', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '73649', 'title': 'Tutti gli uomini del deficiente', 'overview': nan, 'release_date': '1999-12-17', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '57996', 'title': 'Neapolitan Turk', 'overview': nan, 'release_date': '1953-09-16', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '398295', 'title': 'Mundo Cão', 'overview': nan, 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '353713', 'title': 'La nao Capitana', 'overview': nan, 'release_date': '1947-09-29', 'genres': "[{'id': 12, 'name': 'Adventure'}, {'id': 36, 'name': 'History'}]"}
# Dropping {'id': '458335', 'title': 'Soundtrack', 'overview': nan, 'release_date': '2017-07-06', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '298207', 'title': 'Der kleine Nazi', 'overview': nan, 'release_date': '2010-11-18', 'genres': '[]'}
# Dropping {'id': '382995', 'title': 'George !', 'overview': nan, 'release_date': '1972-06-03', 'genres': "[{'id': 10751, 'name': 'Family'}, {'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '439314', 'title': 'The Garden of Afflictions 2017', 'overview': "Brazilian philosopher Olavo de Carvalho's thinking, presented through his presence, his daily work routine and his family life in Virginia (USA).", 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '422005', 'title': 'Tatu and Patu', 'overview': nan, 'release_date': '2016-10-19', 'genres': "[{'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"}
# Dropping {'id': '26969', 'title': '8 Dates', 'overview': nan, 'release_date': '2008-04-18', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '91673', 'title': 'Wolf and Calf', 'overview': nan, 'release_date': '1984-01-01', 'genres': "[{'id': 16, 'name': 'Animation'}]"}
# Dropping {'id': '438910', 'title': 'Engineering Red', 'overview': 'Engineering Red - 1993  Dir: Andrey I. Y. Petrosyan  Medical/art/found footage collage.', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '68063', 'title': 'Questa notte è ancora nostra', 'overview': nan, 'release_date': '2008-03-19', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '433711', 'title': 'All Superheroes Must Die 2: The Last Superhero', 'overview': "In a no holds barred documentary, acclaimed journalist Vicky O'Neil sets out on a quest to uncover the truth behind the murder of small town sweetheart Ally Andrews. What she uncovers, leads her down a dark and twisted rabbit hole into the world of superheroes where she gets the chance of a lifetime, an exclusive interview with Charge, the world's Last Superhero. As he chronicles his mysterious origins and bloody career, Vicky begins to wonder, is he still the hero the world remembers, or has he become the villain we all should fear?", 'release_date': nan, 'genres': "[{'id': 9648, 'name': 'Mystery'}, {'id': 878, 'name': 'Science Fiction'}]"}
# Dropping {'id': '103344', 'title': 'Dépression et des Potes', 'overview': nan, 'release_date': '2012-04-30', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '231216', 'title': 'Villa Henriette', 'overview': nan, 'release_date': '2004-12-02', 'genres': "[{'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '79343', 'title': 'Les fourmis rouges', 'overview': nan, 'release_date': '2007-11-14', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '418757', 'title': 'Między nami dobrze jest', 'overview': nan, 'release_date': '2014-08-01', 'genres': '[]'}
# Dropping {'id': '369444', 'title': 'Ostatni dzwonek', 'overview': nan, 'release_date': '1989-10-27', 'genres': "[{'id': 18, 'name': 'Drama'}]"}
# Dropping {'id': '335251', 'title': 'The Land Where the Blues Began', 'overview': 'An exploration of the musical and social origins of the blues, shot on location in Mississippi in 1978 by Alan Lomax, John Bishop, and Worth Long in association with the Mississippi Authority for Educational Television and broadcast on PBS in 1980. This re-release in 2009 includes two hours of additional music.', 'release_date': nan, 'genres': '[]'}
# Dropping {'id': '395767', 'title': 'Scribe', 'overview': nan, 'release_date': '2017-01-11', 'genres': "[{'id': 53, 'name': 'Thriller'}]"}
# Dropping {'id': '317389', 'title': 'Simbad e il califfo di Bagdad', 'overview': nan, 'release_date': '1973-07-22', 'genres': "[{'id': 12, 'name': 'Adventure'}]"}
# Dropping {'id': '468707', 'title': 'Thick Lashes of Lauri Mäntyvaara', 'overview': nan, 'release_date': '2017-07-28', 'genres': "[{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]"}
# Dropping {'id': '449131', 'title': 'Aprel', 'overview': nan, 'release_date': nan, 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}]"}
# Dropping {'id': '439050', 'title': 'Subdue', 'overview': 'Rising and falling between a man and woman.', 'release_date': nan, 'genres': "[{'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}]"}
# Done importing movies into redis.

# %% [markdown]
# Let's see how many movies we have left, and make sure we can retrieve a movie by ID. 862 is the id for Toy Story. We should see some metadata for them film if we retrieve that key.

# %%
print(len(movies_dict))
data = redis_server.get("862")
movie = json.loads(data)
print(movie)
# Out:
# 44535
# {'id': '862', 'title': 'Toy Story', 'overview': "Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.", 'release_date': '1995-10-30', 'genres': "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"}

# %% [markdown]
# So, with the meta data stored in Redis, it's time to calculate the embeddings and add them to Milvus.
#
# First, we need a collection to store them in. Let's create a simple one that stores the movie ID and embeddings for the *overview* field.
#
# Then, we'll index the overview to make searches more efficent.

# %%
COLLECTION_NAME = 'film_vectors'
PARTITION_NAME = 'Movie'

pk = FieldSchema(name='ID', dtype=DataType.INT64, is_primary=True, auto_id=False)
field = FieldSchema(name='Movies', dtype=DataType.FLOAT_VECTOR, dim=384)
schema = CollectionSchema(fields=[pk, field], description="movie recommender: film vectors")

if utility.has_collection(COLLECTION_NAME): # drop the same collection created before
    collection = Collection(COLLECTION_NAME)
    collection.drop()
    
collection = Collection(name=COLLECTION_NAME, schema=schema)
print("Collection created.")

index_params = {
    "index_type": "IVF_FLAT",
    "metric_type": "L2",
    "params": {"nlist": 128},
}

collection.create_index(field_name="Movies", index_params=index_params)
collection.load()

print("Collection indexed!")
# Out:
# Collection created.
# alloc_timestamp unimplemented, ignore it
# Collection indexed!

# %% [markdown]
# Now, we need a function to create the embeddings.
#
# The primary artifact for movie information is the overview, but including the genre and release date in complete sentences may help with search accuracy.
#
# Let's create a transformer and call it from a simple function that extracts the id field and creates an embed from the overview, genre and release date and inserts the vector into Milvus.

# %%
from sentence_transformers import SentenceTransformer
import ast

def build_genres(data):
    genres = data['genres']
    genre_list = ""
    entries= ast.literal_eval(genres)
    genres = ""
    for entry in entries:
        genre_list = genre_list + entry["name"] + ", "
    genres += genre_list
    genres = "".join(genres.rsplit(",", 1))
    return genres

transformer = SentenceTransformer('all-MiniLM-L6-v2')


def embed_movie(data):
    embed = "{} Released on {}. Genres are {}.".format(data["overview"], data["release_date"], build_genres(data))    
    embeddings = transformer.encode(embed)
    return embeddings

# %% [markdown]
# Now, we can create the embeddings. The data isn't perfectly clean, so we need to check the fields before processing. This should be done in an intial ingestion step, but we're saving an extra pass through the data by doing it here.
#
# This dataset is too large to send to Milvus in a single insert statement, but sending them one at a time would create unnecessary network traffic and add too much time. So, this code uses batches. You can play with the batch size to suit your individual needs and preferences.

# %%
# Parallel arrays for movies ids and embeddings
ids = []
embeds = []

# Loop counter for batching and showing progress
j = 0

for movie_dict in movies_dict:
    try:
        ids.append(int(movie_dict["id"]))
        embeds.append(embed_movie(movie_dict))
        j += 1
        if j % 5000 == 0:
            print("Embedded {} records".format(j))
            data = [ids, embeds]
            collection.insert(data)
            print("Insert completed")
            ids = []
            embeds = []
    except ValueError as ve:
        print("Invalid id: {} for record {}".format(movie_dict["id"], j))

data = [ids, embeds]
collection.insert(data)
print("Final insert completed")
print("Finished with {} embeddings".format(j))
# Out:
# Embedded 5000 records
# Insert completed
# Embedded 10000 records
# Insert completed
# Embedded 15000 records
# Insert completed
# Invalid id: 1997-08-20 for record 19595
# Embedded 20000 records
# Insert completed
# Embedded 25000 records
# Insert completed
# Invalid id: 2012-09-29 for record 29175
# Embedded 30000 records
# Insert completed
# Embedded 35000 records
# Insert completed
# Invalid id: 2014-01-01 for record 35039
# Embedded 40000 records
# Insert completed
# Final insert completed
# Finished with 44532 embeddings

# %% [markdown]
# So, now we can search for movies that match viewer criteria. TO do this, we need several functions.
#
# First, we need a transformer to convert the user's search string to an embedding. **embed_search** does this.
#
# Second, Milvus will return a set of movie ids to us. We need to use them to retrieve movie data from Redis. This happens in **collate_results**.
#
# Finally, **search_for_movies** performs the actual vector search.

# %%
collection.load() # load collection memory before search

# Set search parameters
topK = 5
SEARCH_PARAM = {
    "metric_type":"L2",
    "params":{"nprobe": 20},
}


def embed_search(search_string):
    search_embeddings = transformer.encode(search_string)
    return search_embeddings


def collate_results(ids):
    movies = []    
    for id in ids:
        data = redis_server.get(str(id))
        if data:
            movie = json.loads(data)
            genres = build_genres(movie)
            movie["genres"] = genres
            movies.append(movie)
    return movies


def search_for_movies(search_string):
    user_vector = embed_search(search_string)
    results = collection.search([user_vector],"Movies",param=SEARCH_PARAM, limit=topK, expr=None, output_fields=None)
    return collate_results(results[0].ids)

# %% [markdown]
# So, let's put this search to work!

# %%
from pprint import pprint


search_string = "A movie from the 1990s about vampires."
results = search_for_movies(search_string)
pprint(results)
# Out:
# [{'genres': 'Horror, Science Fiction ',
#   'id': '40028',
#   'overview': 'A science fiction vampire movie. The Vampire is an emissary '
#               'from an embattled world near destruction who teleports to Earth '
#               'to see if they can live here. He finds that our blood is '
#               'nourishing and that at least one source of it is a steady '
#               'stream of transfusions. He hypnotizes a Dr. to provide them and '
#               'has his blond nurse move in to administer them.',
#   'release_date': '1988-05-20',
#   'title': 'Not of This Earth'},
#  {'genres': 'Comedy, Horror ',
#   'id': '65416',
#   'overview': 'A group of friends go on a vacation with some new friends that '
#               'turn out to be vampires, they hire a famous vampire killer to '
#               'help them.',
#   'release_date': '1997-01-24',
#   'title': 'An American Vampire Story'},
#  {'genres': 'Horror, Thriller ',
#   'id': '18392',
#   'overview': 'An 18-year-old college freshman is seduced by a handsome '
#               'vampire lover who introduces her to a dark world of carnal '
#               'desires.',
#   'release_date': '1995-05-30',
#   'title': 'Embrace of the Vampire'},
#  {'genres': 'Thriller, Drama, Horror, Mystery ',
#   'id': '23857',
#   'overview': 'Two roommates discover that the family of one of their '
#               'girlfriends is populated with vampires.',
#   'release_date': '2004-09-17',
#   'title': 'White Skin'},
#  {'genres': 'Mystery, Horror, Thriller ',
#   'id': '11343',
#   'overview': "Vampires are invading a small New England town. It's up to a "
#               'novelist and a young horror fan to save it.',
#   'release_date': '1979-11-17',
#   'title': "Salem's Lot"}]
