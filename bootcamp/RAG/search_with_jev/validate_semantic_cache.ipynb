# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/milvus-io/bootcamp/blob/master/bootcamp/RAG/search_with_jev/validate_semantic_cache.ipynb)[![View on GitHub](https://img.shields.io/badge/View_on-GitHub-181717?logo=github)](https://github.com/milvus-io/bootcamp/blob/master/bootcamp/RAG/search_with_jev/validate_semantic_cache.ipynb)# Check whether a cached answer can be reusedUse Milvus to find a similar cached request, then check task and output compatibility with Jev. Tenant and version boundaries are enforced by code before the model sees candidates.## PreparationRun locally from this directory with `uv sync --python 3.12` and `uv run jupyter lab`, or install the notebook dependencies in Colab:

# %%
# In Colab, uncomment this setup cell. Local users should use uv sync --python 3.12.
# %pip install "pymilvus>=2.5,<2.6.10" "milvus-lite>=2.5,<3" "setuptools<71" "google-genai>=1.68,<2" numpy requests

# %% [markdown]
# > In Colab, restart the runtime after installing dependencies if needed.Set `GEMINI_API_KEY` and `TYPESAFE_API_KEY` in your environment or enter them privately below. A `GOOGLE_API_KEY` is also accepted for Gemini. Obtain a Gemini key from [Google AI Studio](https://aistudio.google.com/apikey). Gemini embeds the synthetic documents and queries; TypeSafe receives the sample evidence and judgment questions. Both services require API access and may consume credits.The helper batches independent questions into one request. IDs map responses back to code; the instructions explicitly identify each field being judged. HTTP failures stop the tutorial rather than produce fabricated scores.

# %%
import getpass
import json
import math
import os
import time
import uuid

import requests
from pymilvus import DataType, MilvusClient
import numpy as np
from google import genai
from google.genai import types

if not os.getenv("TYPESAFE_API_KEY"):
    os.environ["TYPESAFE_API_KEY"] = getpass.getpass("TypeSafe API key: ")

if not os.getenv("GEMINI_API_KEY"):
    os.environ["GEMINI_API_KEY"] = os.getenv("GOOGLE_API_KEY") or getpass.getpass(
        "Gemini API key: "
    )

MODEL = os.getenv("JEV_MODEL", "jev-1.13.0")
API_URL = "https://api.typesafe.ai/v1/systemone"
call_log = []

# %% [markdown]
# ### Call JevThis helper sends independent questions in one request and validates the returned answers.

# %%
def judge(state, questions):
    """Call Jev with bounded retries; stop on invalid or incomplete responses."""
    for attempt in range(3):
        started = time.perf_counter()
        response = requests.post(
            API_URL,
            headers={"Authorization": f"Bearer {os.environ['TYPESAFE_API_KEY']}"},
            json={"model": MODEL, "state": state, "questions": questions},
            timeout=45,
        )
        if response.status_code in (429, 500, 502, 503, 504) and attempt < 2:
            time.sleep(2**attempt)
            continue
        response.raise_for_status()
        body = response.json()
        answers = body["answers"]
        if set(answers) != set(questions):
            raise ValueError("Jev returned missing or unexpected question IDs")
        for key, question in questions.items():
            answer = answers[key]
            if question["type"] == "noul":
                value = float(answer["noul"])
                if not math.isfinite(value) or not 0 <= value <= 1:
                    raise ValueError("Invalid Noul probability")
            elif answer["choice"] not in question["criteria"]:
                raise ValueError("Unexpected Choice option")
        call_log.append(
            {
                "seconds": round(time.perf_counter() - started, 3),
                "usage": body.get("usage", {}),
                "model": MODEL,
            }
        )
        return answers
    raise RuntimeError("Jev request failed")


def noul(instructions):
    return {
        "type": "noul",
        "instructions": instructions,
        "criteria": {
            "true": "The stated condition is supported by the supplied data.",
            "false": "The condition is unsupported or contradicted.",
        },
    }

# %% [markdown]
# ## Prepare a small corpusAll names and records below are synthetic teaching examples.

# %%
documents = [
    {
        "id": 1,
        "text": "How do I install Atlas v2 with Docker?",
        "answer": "Install Docker, download the v2 compose file, then run docker compose up.",
        "tenant": "public",
        "version": "v2",
    },
    {
        "id": 2,
        "text": "How do I install Atlas v1?",
        "answer": "Run the legacy v1 setup script.",
        "tenant": "public",
        "version": "v1",
    },
]

# %% [markdown]
# ## Connect to MilvusFor `MilvusClient`:- Use a local file such as `./search_with_jev.db` for [Milvus Lite](https://milvus.io/docs/milvus_lite.md).- Set `MILVUS_URI` to a server endpoint such as `http://localhost:19530` for [Milvus on Docker or Kubernetes](https://milvus.io/docs/quickstart.md).- For [Zilliz Cloud](https://zilliz.com/cloud), set `MILVUS_URI` to the public endpoint and `MILVUS_TOKEN` to your API key.Each run uses its own collection name. Cleanup removes only that collection.

# %%
client = MilvusClient(
    uri=os.getenv("MILVUS_URI", "./search_with_jev.db"),
    token=os.getenv("MILVUS_TOKEN", ""),
)
collection_name = "jev_demo_" + uuid.uuid4().hex[:12]

# %% [markdown]
# ## Encode the sample documentsUse [Gemini Embedding 2](https://ai.google.dev/gemini-api/docs/embeddings) to generate 768-dimensional semantic vectors. Milvus stores these vectors and retrieves candidates by cosine similarity; Jev judges the retrieved text afterward.For this model, the retrieval task is specified in the input text, not the API's `task_type` field. Documents use `title: none | text: ...`, while queries use `task: search result | query: ...`. Each document is embedded separately because passing multiple inputs to Embedding 2 can aggregate them into one vector. The model normalizes its 768-dimensional output automatically.Keep the model, dimension and formatting consistent between indexing and searching. If you change the embedding configuration, regenerate the document vectors and recreate the collection. These tiny examples fit within the model's input limit; split longer source documents into chunks before embedding them.

# %%
EMBEDDING_MODEL = "gemini-embedding-2"
EMBEDDING_DIMENSION = 768
embedding_client = genai.Client(
    api_key=os.environ["GEMINI_API_KEY"],
    http_options=types.HttpOptions(
        timeout=60000,
        retry_options=types.HttpRetryOptions(attempts=3),
    ),
)


def embed_text(text):
    """Embed one input, validating the vector before storing or searching."""
    result = embedding_client.models.embed_content(
        model=EMBEDDING_MODEL,
        contents=text,
        config=types.EmbedContentConfig(
            output_dimensionality=EMBEDDING_DIMENSION,
        ),
    )
    if not result.embeddings or len(result.embeddings) != 1:
        raise ValueError("Expected exactly one embedding per input")
    vector = np.asarray(result.embeddings[0].values, dtype=np.float32)
    if vector.shape != (EMBEDDING_DIMENSION,) or not np.isfinite(vector).all():
        raise ValueError("Invalid embedding dimension or values")
    if not np.linalg.norm(vector):
        raise ValueError("Received a zero embedding")
    return vector


# Embed documents separately: Embedding 2 can aggregate multiple inputs.
vectors = np.stack(
    [embed_text(f"title: none | text: {row['text']}") for row in documents]
)
print(f"Embedded {len(vectors)} documents with {EMBEDDING_MODEL}: {vectors.shape}")
# Out:
# Embedded 2 documents with gemini-embedding-2: (2, 768)

# %% [markdown]
# ## Create the collectionDefine the primary key, vector and text fields explicitly. Additional sample metadata is stored in dynamic fields. The vector index and search both use cosine similarity.

# %%
schema = client.create_schema(auto_id=False, enable_dynamic_field=True)
schema.add_field(field_name="id", datatype=DataType.INT64, is_primary=True)
schema.add_field(
    field_name="vector", datatype=DataType.FLOAT_VECTOR, dim=vectors.shape[1]
)
schema.add_field(field_name="text", datatype=DataType.VARCHAR, max_length=8192)
index_params = client.prepare_index_params()
index_params.add_index(
    field_name="vector", index_type="AUTOINDEX", metric_type="COSINE"
)
if not client.has_collection(collection_name=collection_name):
    client.create_collection(
        collection_name=collection_name,
        schema=schema,
        index_params=index_params,
        # consistency_level="Strong",
    )

# %% [markdown]
# ## Insert the documentsWrite the document text, metadata and vectors to Milvus.

# %%
client.insert(
    collection_name=collection_name,
    data=[dict(row, vector=vector.tolist()) for row, vector in zip(documents, vectors)],
)
# Out:
# {'insert_count': 2, 'ids': [1, 2], 'cost': 0}

# %% [markdown]
# ## Retrieve candidatesReturn only text and sample metadata, keeping vectors out of the Jev request. Strong consistency makes newly inserted documents searchable immediately.

# %%
output_fields = sorted({key for row in documents for key in row if key != "vector"})


def retrieve(query, limit=5, filter_expr=""):
    vector = embed_text(f"task: search result | query: {query}")
    hits = client.search(
        collection_name=collection_name,
        data=[vector.tolist()],
        anns_field="vector",
        limit=limit,
        filter=filter_expr,
        output_fields=output_fields,
        search_params={"metric_type": "COSINE", "params": {}},
        consistency_level="Strong",
    )[0]
    return [
        dict(
            {key: value for key, value in hit["entity"].items() if key != "vector"},
            id=hit["id"],
            retrieval_score=hit["distance"],
        )
        for hit in hits
    ]

# %% [markdown]
# ## Compare a reusable request and a language mismatchThere are two cached question/answer pairs, one per version. The exact tenant/version filter leaves one eligible v2 record, and Milvus retrieves Top 1. Both new requests describe the same installation task, but only one explicitly permits the cached English answer to be returned unchanged. No new documents are needed for this positive/negative comparison.

# %%
requests_to_check = [
    "In English, tell me how to set up Atlas v2 using Docker.",
    "Explain how to install Atlas v2 with Docker in Spanish.",
]
REUSE_THRESHOLD = 0.8
cache_rows = []
for query in requests_to_check:
    candidates = retrieve(query, limit=1, filter_expr='tenant == "public" and version == "v2"')
    if not candidates:
        cache_rows.append((query, "None", "-", "-", "-", "Cache miss"))
        continue
    candidate = candidates[0]
    answers = judge(
        {"current_request": query, "cached_request": candidate["text"],
         "cached_answer": candidate["answer"]},
        {
            "task": noul("Do `current_request` and `cached_request` ask for the same substantive task and version?"),
            "format": noul(
                "Considering only the explicitly requested output language and presentation "
                "format, does `cached_answer` comply with `current_request` without editing? "
                "Ordinary English prose satisfies a request for English with no special "
                "format. English prose does not satisfy a request for Spanish. Do not "
                "evaluate factual completeness or wording similarity in this check."
            ),
            "context": noul("Is `current_request` self-contained, without missing prior turns or user-specific information needed to reuse `cached_answer`?"),
        },
    )
    scores = {key: answer["noul"] for key, answer in answers.items()}
    reusable = min(scores.values()) >= REUSE_THRESHOLD
    cache_rows.append((query, candidate["id"], f"{scores['task']:.3f}",
                       f"{scores['format']:.3f}", f"{scores['context']:.3f}",
                       "Reuse" if reusable else "Cache miss"))
    failed_checks = [key for key, score in scores.items() if score < REUSE_THRESHOLD]
    print("Request:", query)
    print("Candidate answer:", candidate["answer"])
    print("Checks below threshold:", failed_checks)
    print("Returned answer:", candidate["answer"] if reusable else None)
# Out:
# Request: In English, tell me how to set up Atlas v2 using Docker.
# Candidate answer: Install Docker, download the v2 compose file, then run docker compose up.
# Checks below threshold: []
# Returned answer: Install Docker, download the v2 compose file, then run docker compose up.
# Request: Explain how to install Atlas v2 with Docker in Spanish.
# Candidate answer: Install Docker, download the v2 compose file, then run docker compose up.
# Checks below threshold: ['format', 'context']
# Returned answer: None

# %% [markdown]
# The format question checks language and presentation only; task compatibility and missing conversational context have separate questions. The gate requires **all three** scores to reach 0.8. The English paraphrase is an intended positive case, but inspect the observed scores rather than assuming it must pass. For the Spanish request, language incompatibility alone is enough to reject reuse; any other failed dimension is also shown. This checks reuse compatibility, not factual correctness of the cached answer. A cache miss is returned to the caller; this notebook does not invoke an answering model or translate cached text.

# %%
from IPython.display import Markdown, display


def show_table(headers, rows):
    def escape(value):
        return str(value).replace("|", "&#124;").replace("\n", " ")
    lines = ["| " + " | ".join(headers) + " |",
             "| " + " | ".join(["---"] * len(headers)) + " |"]
    lines.extend("| " + " | ".join(escape(v) for v in row) + " |" for row in rows)
    display(Markdown("\n".join(lines)))

show_table(["Request", "Cache ID", "Task", "Format", "Context", "Decision"], cache_rows)
# Out:
# | Request | Cache ID | Task | Format | Context | Decision |
# | --- | --- | --- | --- | --- | --- |
# | In English, tell me how to set up Atlas v2 using Docker. | 1 | 0.950 | 0.930 | 0.860 | Reuse |
# | Explain how to install Atlas v2 with Docker in Spanish. | 1 | 0.890 | 0.030 | 0.770 | Cache miss |

# %% [markdown]
# ## Inspect usage and clean upThe raw usage fields and request duration help inspect this run. They are not a latency benchmark.

# %%
print(json.dumps(call_log, indent=2))
client.drop_collection(collection_name=collection_name)
client.close()
embedding_client.close()
# Out:
# [
#   {
#     "seconds": 0.614,
#     "usage": {
#       "input_tokens": 555,
#       "output_tokens": 52
#     },
#     "model": "jev-1.13.0"
#   },
#   {
#     "seconds": 0.603,
#     "usage": {
#       "input_tokens": 553,
#       "output_tokens": 52
#     },
#     "model": "jev-1.13.0"
#   }
# ]

# %% [markdown]
# ## Next stepsThe thresholds in this example are starting points, not calibrated production defaults. Independent questions share state but do not see each other's answers. See the [Jev primitives](https://docs.typesafe.ai/primitives) and the [cookbook index](https://github.com/milvus-io/bootcamp/blob/master/bootcamp/RAG/search_with_jev/README.md).For a larger example, see GPTCache's [Jev implementation](https://github.com/zilliztech/GPTCache/blob/main/gptcache/similarity_evaluation/jev.py) and [evaluation](https://github.com/zilliztech/GPTCache/blob/main/examples/benchmark/reuse_compatibility/README.md).
